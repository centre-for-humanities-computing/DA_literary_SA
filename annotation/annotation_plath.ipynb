# %% [markdown]
# # hent tekst og annoter

# %%
import json
import pandas as pd

# %%
with open('ariel_lines.json') as f:
    data = json.load(f)

data
# Out:
# ['MORNING SONG',
#  'Love set you going like a fat gold watch.',
#  'The midwife slapped your footsoles, and your bald cry',
#  'Took its place among the elements.',
#  'Our voices echo, magnifying your arrival. New statue.',
#  'In a drafty museum, your nakedness',
#  'Shadows our safety. We stand round blankly as walls.',
#  "I'm no more your mother",
#  'Than the cloud that distills a mirror to reflect its own slow',
#  'Effacement at the wind 5 hand.',
#  'All night your moth-breath',
#  'Flickers among the flat pink roses. I wake to listen:',
#  'A far sea moves in my ear.',
#  'One cry, and I stumble from bed, cow-heavy and floral',
#  'In my Victorian nightgown.',
#  'Your mouth opens clean as a cats. The window square',
#  'Whitens and swallows its dull stars. And now you try',
#  'Your handful of notes;',
#  'The clear vowels rise like balloons.',
#  'THE COURIERS',
#  'The word of a snail on the plate of a leaf?',
#  'It is not mine. Do not accept it.',
#  'Acetic acid in a sealed tin?',
#  'Do not accept it. It is not genuine.',
#  'A ring of gold with the sun in it?',
#  'Lies. Lies and a grief.',
#  'Frost on a leaf, the immaculate',
#  'Cauldron, talking and crackling',
#  'All to itself on top of each',
#  'Of nine black Alps.',
#  'A disturbance in mirrors,',
#  'The sea shattering its gray one—',
#  'Love, love, my season.',
#  'SHEEP IN FOG',
#  'The hills step off into whiteness.',
#  'People or stars',
#  'Regard me sadly, I disappoint them.',
#  'The train leaves a line of breath.',
#  'O slow',
#  'Horse the color of rust,',
#  'Hooves, dolorous bells—',
#  'All morning the',
#  'Morning has been blackening,',
#  'A flower left out.',
#  'My bones hold a stillness, the far',
#  'Fields melt my heart.',
#  'They threaten',
#  'To let me through to a heaven',
#  'Starless and fatherless, a dark water.',
#  'THE APPLICANT',
#  'First, are you our sort of a person?',
#  'Do you wear',
#  'A glass eye, false teeth or a crutch,',
#  'A brace or a hook,',
#  'Rubber breasts or a rubber crotch,',
#  "Stitches to show something's missing? No, no? Then",
#  'How can we give you a thing?',
#  'Stop crying.',
#  'Open your hand.',
#  'Empty? Empty. Here is a hand',
#  'To fill it and willing',
#  'To bring teacups and roll away headaches',
#  'And do whatever you tell it.',
#  'Will you marry it?',
#  'It is guaranteed',
#  'To thumb shut your eyes at the end',
#  'And dissolve of sorrow.',
#  'We make new stock from the salt.',
#  'I notice you are stark naked.',
#  'How about this suit—',
#  'Black and stiff, but not a bad fit.',
#  'Will you marry it?',
#  'It is waterproof, shatterproof, proof',
#  'Against fire and bombs through the roof.',
#  'Believe me, they”Il bury you in it.',
#  'Now your head, excuse me, is empty.',
#  'I have the ticket for that.',
#  'Come here, sweetie, out of the closet.',
#  'Well, what do you think of that?',
#  'Naked as paper to start',
#  'But in twenty-five years she”ll be silver,',
#  'In fifty, gold.',
#  'A living doll, everywhere you look.',
#  'Tt can sew, it can cook,',
#  'It can talk, talk, talk.',
#  'It works, there is nothing wrong with it.',
#  "You have a hole, it's a poultice.",
#  "You have an eye, it's an image.",
#  "My boy, it's your last resort.",
#  'Will you marry it, marry it, marry it.',
#  'LADY LAZARUS',
#  'I have done it again.',
#  'One year in every ten',
#  'TI manage it—',
#  'A sort of walking miracle, my skin',
#  'Bright as a Nazi lampshade,',
#  'My right foot',
#  'A paperweight,',
#  'My face a featureless, fine',
#  'Jew linen.',
#  'Peel off the napkin',
#  'O my enemy.',
#  'Do I terrify?—',
#  'The nose, the eye pits, the full set of teeth?',
#  'The sour breath',
#  'Will vanish in a day.',
#  'Soon, soon the flesh',
#  'The grave cave ate will be',
#  'At home on me',
#  'And I a smiling woman. I am only thirty.',
#  'And like the cat I have nine times to die.',
#  'This is Number Three.',
#  'What a trash',
#  'To annihilate each decade.',
#  'What a million filaments.',
#  'The peanut-crunching crowd',
#  'Shoves in to see',
#  'Them unwrap me hand and foot—',
#  'The big strip tease.',
#  'Gentlemen, ladies',
#  'These are my hands',
#  'My knees.',
#  'I may be skin and bone,',
#  'Nevertheless, I am the same, identical woman.',
#  'The first time it happened I was ten.',
#  'Tt was an accident.',
#  'The second time I meant',
#  'To last it out and not come back at all.',
#  'I rocked shut',
#  'As a seashell.',
#  'They had to call and call',
#  'And pick the worms off me like sticky pearls.',
#  'Dying',
#  'Is an art, like everything else.',
#  'I do it exceptionally well.',
#  'I do it so it feels like hell.',
#  'I do it so it feels real.',
#  'I guess you could say Ive a call.',
#  "It's easy enough to do it in a cell.",
#  "It's easy enough to do it and stay put.",
#  "It's the theatrical",
#  'Comeback in broad day',
#  'To the same place, the same face, the same brute',
#  'Amused shout:',
#  '“A miracle!”',
#  'That knocks me out.',
#  'There is a charge',
#  'For the eyeing of my scars, there is a charge',
#  'For the hearing of my heart—',
#  'It really goes.',
#  'And there is a charge, a very large charge',
#  'For a word or a touch',
#  'Or a bit of blood',
#  'Or a piece of my hair or my clothes.',
#  'So, so, Herr Doktor.',
#  'So, Herr Enemy.',
#  'I am your opus, I am your valuable,',
#  'The pure gold baby',
#  'That melts to a shriek.',
#  'I turn and burn.',
#  'Do not think I underestimate your great concern.',
#  'Ash, ash—',
#  'You poke and stir.',
#  'Flesh, bone, there is nothing there—',
#  'A cake of soap,',
#  'A wedding ring,',
#  'A gold filling.',
#  'Herr God, Herr Lucifer',
#  'Beware',
#  'Beware.',
#  'Out of the ash',
#  'I rise with my red hair',
#  'And I eat men like air.',
#  'TULIPS',
#  'The tulips are too excitable, it is winter here.',
#  'Look how white everything is, how quiet, how snowed-in. I am learning peacefulness, lying by myself quietly',
#  'As the light lies on these white walls, this bed, these hands. I am nobody; I have nothing to do with explosions.',
#  'I have given my name and my day-clothes up to the nurses',
#  'And my history to the anaesthetist and my body to surgeons.',
#  'They have propped my head between the pillow and the sheet-cuff',
#  'Like an eye between two white lids that will not shut.',
#  'Stupid pupil, it has to take everything in.',
#  'The nurses pass and pass, they are no trouble,',
#  'They pass the way gulls pass inland in their white caps,',
#  'Doing things with their hands, one just the same as another,',
#  'So it is impossible to tell how many there are.',
#  'My body is a pebble to them, they tend it as water',
#  'Tends to the pebbles it must run over, smoothing them gently.',
#  'They bring me numbness in their bright needles, they bring me sleep.',
#  'Now I have lost myself I am sick of baggage—',
#  'My patent leather overnight case like a black pillbox,',
#  'My husband and child smiling out of the family photo;',
#  'Their smiles catch onto my skin, little smiling hooks.',
#  'I have let things slip, a thirty-year-old cargo boat',
#  'Stubbornly hanging on to my name and address.',
#  'They have swabbed me clear of my loving associations.',
#  'Scared and bare on the green plastic-pillowed trolley',
#  'I watched my teaset, my bureaus of linen, my books',
#  'Sink out of sight, and the water went over my head.',
#  'I am a nun now, I have never been so pure.',
#  'I didnt want any flowers, I only wanted',
#  'To lie with my hands turned up and be utterly empty.',
#  'How free it is, you have no idea how free—',
#  'The peacefulness is so big it dazes you,',
#  'And it asks nothing, a name tag, a few trinkets.',
#  'It is what the dead close on, finally; I imagine them',
#  'Shutting their mouths on it, like a Communion tablet.',
#  'The tulips are too red in the first place, they hurt me.',
#  'Even through the gift paper I could hear them breathe',
#  'Lightly, through their white swaddlings, like an awful baby.',
#  'Their redness talks to my wound, it corresponds.',
#  'They are subtle: they seem to float, though they weigh me down,',
#  'Upsetting me with their sudden tongues and their color,',
#  'A dozen red lead sinkers round my neck.',
#  'Nobody watched me before, now I am watched.',
#  'The tulips turn to me, and the window behind me',
#  'Where once a day the light slowly widens and slowly thins,',
#  'And I see myself, flat, ridiculous, a cut-paper shadow',
#  'Between the eye of the sun and the eyes of the tulips,',
#  'And I have no face, I have wanted to efface myself.',
#  'The vivid tulips eat my oxygen.',
#  'Before they came the air was calm enough,',
#  'Coming and going, breath by breath, without any fuss.',
#  'Then the tulips filled it up like a loud noise.',
#  'Now the air snags and eddies round them the way a river',
#  'Snags and eddies round a sunken rust-red engine.',
#  'They concentrate my attention, that was happy',
#  'Playing and resting without committing itself.',
#  'The walls, also, seem to be warming themselves.',
#  'The tulips should be behind bars like dangerous animals;',
#  'They are opening like the mouth of some great African cat,',
#  'And I am aware of my heart: it opens and closes',
#  'Its bowl of red blooms out of sheer love of me.',
#  'The water I taste is warm and salt, like the sea,',
#  'And comes from a country far away as health.',
#  'CUT',
#  'What a thrill—',
#  'My thumb instead of an onion.',
#  'The top quite gone',
#  'Except for a sort of a hinge',
#  'Of skin,',
#  'A flap like a hat,',
#  'Dead white.',
#  'Then that red plush.',
#  'Little pilgrim,',
#  'The Indians axed your scalp.',
#  'Your turkey wattle',
#  'Carpet rolls',
#  'Straight from the heart.',
#  'I step on it,',
#  'Clutching my bottle',
#  'Of pink fizz.',
#  'A celebration, this is.',
#  'Out of a gap',
#  'A million soldiers run,',
#  'Redcoats, every one.',
#  'Whose side are they on?',
#  'O my',
#  'Homunculus, I am ill.',
#  'I have taken a pill to kill',
#  'The thin',
#  'Papery feeling.',
#  'Saboteur,',
#  'Kamikaze man—',
#  'The stain on your',
#  'Gauze Ku Klux Klan',
#  'Babushka',
#  'Darkens and tarnishes and when',
#  'The balled',
#  'Pulp of your heart',
#  'Confronts its small',
#  'Mill of silence',
#  'How you jump—',
#  'Trepanned veteran,',
#  'Dirty girl,',
#  'Thumb stump.',
#  'ELM',
#  'I know the bottom, she says. I know it with my great tap root:',
#  'It is what you fear.',
#  'I do not fear it: I have been there.',
#  'Is it the sea you hear in me,',
#  'Its dissatisfactions?',
#  'Or the voice of nothing, that was your madness?',
#  'Love is a shadow.',
#  'How you lie and cry after it',
#  'Listen: these are its hooves: it has gone off, like a horse.',
#  'AI! night I shall gallop thus, impetuously,',
#  'Till your head is a stone, your pillow a little turf,',
#  'Echoing, echoing.',
#  'Or shall I bring you the sound of poisons?',
#  'This is rain now, this big hush.',
#  'And this is the fruit of it: tin-white, like arsenic.',
#  'I have suffered the atrocity of sunsets.',
#  'Scorched to the root',
#  'My red filaments burn and stand, a hand of wires.',
#  'Now I break up in pieces that fly about like clubs.',
#  'A wind of such violence',
#  'Will tolerate no bystanding: I must shriek.',
#  'The moon, also, is merciless: she would drag me',
#  'Cruelly, being barren.',
#  'Her radiance scathes me. Or perhaps I have caught her.',
#  'I let her go. I let her go',
#  'Diminished and flat, as after radical surgery.',
#  'How your bad dreams possess and endow me.',
#  'I am inhabited by a cry.',
#  'Nightly it flaps out',
#  'Looking, with its hooks, for something to love.',
#  'I am terrified by this dark thing',
#  'That sleeps in me;',
#  'All day I feel its soft, feathery turnings, its malignity.',
#  'Clouds pass and disperse.',
#  'Are those the faces of love, those pale irretrievables?',
#  'Is it for such I agitate my heart?',
#  'I am incapable of more knowledge.',
#  'What is this, this face',
#  'So murderous in its strangle of branches ?—',
#  'Its snaky acids hiss.',
#  'It petrifies the will. These are the isolate, slow faults',
#  'That kill, that kill, that kill.',
#  'THE NIGHT DANCES',
#  'A smile fell in the grass.',
#  'Irretrievable!',
#  'And how will your night dances',
#  'Lose themselves. In mathematics?',
#  'Such pure leaps and spirals—',
#  'Surely they travel',
#  'The world forever, I shall not entirely',
#  'Sit emptied of beauties, the gift',
#  'Of your small breath, the drenched grass',
#  'Smell of your sleeps, lilies, lilies.',
#  'Their flesh bears no relation.',
#  'Cold folds of ego, the calla,',
#  'And the tiger, embellishing itself—',
#  'Spots, and a spread of hot petals.',
#  'The comets',
#  'Have such a space to cross,',
#  'Such coldness, forgetfulness.',
#  'So your gestures flake off—',
#  'Warm and human, then their pink light',
#  'Bleeding and peeling',
#  'Through the black amnesias of heaven.',
#  'Why am I given',
#  'These lamps, these planets',
#  'Falling like blessings, like flakes',
#  'Six-sided, white',
#  'On my eyes, my lips, my hair',
#  'Touching and melting.',
#  'Nowhere.',
#  'POPPIES IN OCTOBER',
#  'Even the sun-clouds this morning cannot manage such skirts.',
#  'Nor the woman in the ambulance',
#  'Whose red heart blooms through her coat so astoundingly—',
#  'A gift, a love gift',
#  'Utterly unasked for',
#  'By a sky',
#  'Palely and flamily',
#  'Igniting its carbon monoxides, by eyes',
#  'Dulled to a halt under bowlers.',
#  'O my God, what am I',
#  'That these late mouths should cry open',
#  'In a forest of frost, in a dawn of cornflowers.',
#  'BERCK-PLAGE',
#  'This is the sea, then, this great abeyance.',
#  'How the sun poultice draws on my inflammation.',
#  'Electrifyingly-colored sherbets, scooped from the freeze',
#  'By pale girls, travel the air in scorched hands.',
#  'Why is it so quiet, what are they hiding?',
#  'I have two legs, and I move smilingly.',
#  'A sandy damper kills the vibrations;',
#  'It stretches for miles, the shrunk voices',
#  'Waving and crutchless, half their old size.',
#  'The line of the eye, scalded by these bald surfaces,',
#  'Boomerang like anchored elastics, hurting the owner.',
#  'Is it any wonder he puts on dark glasses?',
#  'Is it any wonder he affects a black cassock?',
#  'Here he comes now, among the mackerel gatherers',
#  'Who wall up their backs against him.',
#  'They are handling the black and green lozenges like the parts of a body.',
#  'The sea, that crystallized these,',
#  'Creeps away, many-snaked, with a long hiss of distress.',
#  'This black boot has no mercy for anybody.',
#  'Why should it, it is the hearse of a dead foot,',
#  'The high, dead, toeless foot of this priest',
#  'Who plumbs the well of his book,',
#  'The bent print bulging before him like scenery.',
#  'Obscene bikinis hide in the dunes,',
#  "Breasts and hips a confectioner 's sugar",
#  'Of little crystals, titillating the light,',
#  'While a green pool opens its eye,',
#  'Sick with what it has swallowed—',
#  'Limbs, images, shrieks. Behind the concrete bunkers',
#  'Two lovers unstick themselves.',
#  'O white sea-crockery,',
#  'What cupped sighs, what salt in the throat...',
#  'And the onlooker, trembling,',
#  'Drawn like a long material',
#  'Through a still virulence,',
#  'And a weed, hairy as privates.',
#  'On the balconies of the hotel, things are glittering.',
#  'Things, things—',
#  'Tubular steel wheelchairs, aluminum crutches.',
#  'Such salt-sweetness. Why should I walk',
#  'Beyond the breakwater, spotty with barnacles? I am not a nurse, white and attendant,',
#  'I am not a smile.',
#  'These children are after something, with hooks and cries,',
#  'And my heart too small to bandage their terrible faults.',
#  'This is the side of a man: his red ribs,',
#  'The nerves bursting like trees, and this is the surgeon:',
#  'One mirrory eye—',
#  'A facet of knowledge.',
#  'On a striped mattress in one room',
#  'An old man is vanishing.',
#  'There is no help in his weeping wife.',
#  'Where are the eye-stones, yellow and valuable,',
#  'And the tongue, sapphire of ash.',
#  'A wedding-cake face in a paper frill.',
#  'How superior he is now.',
#  'It is like possessing a saint.',
#  'The nurses in their wing-caps are no longer so beautiful;',
#  'They are browning, like touched gardenias.',
#  'The bed is rolled from the wall.',
#  'This is what it is to be complete. It is horrible.',
#  'Is he wearing pajamas or an evening suit',
#  'Under the glued sheet from which his powdery beak',
#  'Rises so whitely unbuffeted?',
#  'They propped his jaw with a book until it stiffened',
#  'And folded his hands, that were shaking: goodbye, goodbye.',
#  'Now the washed sheets fly in the sun,',
#  'The pillow cases are sweetening.',
#  'It is a blessing, it is a blessing:',
#  'The long coffin of soap-colored oak,',
#  'The curious bearers and the raw date',
#  'Engraving itself in silver with marvelous calm.',
#  'The grey sky lowers, the hills like a green sea',
#  'Run fold upon fold far off, concealing their hollows,',
#  'The hollows in which rock the thoughts of the wife—',
#  'Blunt, practical boats',
#  'Full of dresses and hats and china and married daughters.',
#  'In the parlor of the stone house',
#  'One curtain is flickering from the open window,',
#  'Flickering and pouring, a pitiful candle.',
#  'This is the tongue of the dead man: remember, remember.',
#  'How far he is now, his actions',
#  'Around him like livingroom furniture, like a décor.',
#  'As the pallors gather—',
#  'The pallors of hands and neighborly faces,',
#  'The elate pallors of flying iris.',
#  'They are flying off into nothing: remember us.',
#  'The empty benches of memory look over stones,',
#  'Marble facades with blue veins, and jelly-glassfuls of daffodils.',
#  'It is so beautiful up here: it is a stopping place.',
#  'The natural fatness of these lime leaves! —',
#  'Pollarded green balls, the trees march to church.',
#  'The voice of the priest, in thin air,',
#  'Meets the corpse at the gate,',
#  'Addressing it, while the hills roll the notes of the dead bell;',
#  'A glitter of wheat and crude earth.',
#  'What is the name of that color?—',
#  'Old blood of caked walls the sun heals,',
#  'Old blood of limb stumps, burnt hearts.',
#  'The widow with her black pocketbook and three daughters,',
#  'Necessary among the flowers,',
#  'Enfolds her face like fine linen,',
#  'Not to be spread again.',
#  'While a sky, wormy with put-by smiles,',
#  'Passes cloud after cloud.',
#  'And the bride flowers expend a freshness,',
#  'And the soul is a bride',
#  'In a still place, and the groom is red and forgetful, he is featureless.',
#  'Behind the glass of this car',
#  'The world purrs, shut-off and gentle.',
#  'And I am dark-suited and still, a member of the party,',
#  'Gliding up in low gear behind the cart.',
#  'And the priest is a vessel,',
#  'A tarred fabric, sorry and dull,',
#  'Following the coffin on its flowery cart like a beautiful woman,',
#  'A crest of breasts, eyelids and lips',
#  'Storming the hilltop.',
#  'Then, from the barred yard, the children',
#  'Smell the melt of shoe-blacking,',
#  'Their faces turning, wordless and slow,',
#  'Their eyes opening',
#  'On a wonderful thing—',
#  'Six round black hats in the grass and a lozenge of wood,',
#  'And a naked mouth, red and awkward.',
#  'For a minute the sky pours into the hole like plasma.',
#  'There is no hope, it is given up.',
#  'ARIEL',
#  'Stasis in darkness.',
#  'Then the substanceless blue',
#  'Pour of tor and distances.',
#  "God's lioness,",
#  'How one we grow,',
#  'Pivot of heels and knees! —The furrow',
#  'Splits and passes, sister to',
#  'The brown arc',
#  'Of the neck I cannot catch,',
#  'Nigger-eye',
#  'Berries cast dark',
#  'Hooks—',
#  'Black sweet blood mouthfuls,',
#  'Shadows.',
#  'Something else',
#  'Hauls me through air—',
#  'Thighs, hair;',
#  'Flakes from my heels.',
#  'White',
#  'Godiva, I unpeel—',
#  'Dead hands, dead stringencies.',
#  'And now I',
#  'Foam to wheat, a glitter of seas.',
#  'The child cry',
#  'Melts in the wall.',
#  'And I',
#  'Am the arrow,',
#  'The dew that flies',
#  'Suicidal, at one with the drive',
#  'Into the red',
#  'Eye, the cauldron of morning.',
#  'DEATH & CO.',
#  'Two, of course there are two.',
#  'It seems perfectly natural now—',
#  'The one who never looks up, whose eyes are lidded',
#  "And balled, like Blake's,",
#  'Who exhibits',
#  'The birthmarks that are his trademark—',
#  'The scald scar of water,',
#  'The nude',
#  'Verdigris of the condor.',
#  'I am red meat. His beak',
#  'Claps sidewise: I am not his yet.',
#  'He tells me how badly I photograph.',
#  'He tells me how sweet',
#  'The babies look in their hospital',
#  'Icebox, a simple',
#  'Frill at the neck,',
#  'Then the flutings of their lonian',
#  'Death-gowns,',
#  'Then two little feet.',
#  'He does not smile or smoke.',
#  'The other does that,',
#  'His hair long and plausive.',
#  'Bastard',
#  'Masturbating a glitter,',
#  'He wants to be loved.',
#  'I do not stir.',
#  'The frost makes a flower,',
#  'The dew makes a star,',
#  'The dead bell,',
#  'The dead bell.',
#  'Somebody done for.',
#  'NICK AND THE CLANDESTICK',
#  'I am a miner. The light burns blue.',
#  'Waxy stalactites',
#  'Drip and thicken, tears',
#  'The earthen womb',
#  'Exudes from its dead boredom.',
#  'Black bat airs',
#  'Wrap me, raggy shawls,',
#  'Cold homicides.',
#  'They weld to me like plums.',
#  'Old cave of calcium',
#  'Icicles, old echoer.',
#  'Even the newts are white,',
#  'Those holy Joes.',
#  'And the fish, the fish—',
#  'Christ! they are panes of ice,',
#  'A vice of knives,',
#  'A piranha',
#  'Religion, drinking',
#  'Its first communion out of my live toes.',
#  'The candle',
#  'Gulps and recovers its small altitude,',
#  'Its yellows hearten.',
#  'O love, how did you get here?',
#  'O embryo',
#  'Remembering, even in sleep,',
#  'Your crossed position.',
#  'The blood blooms clean',
#  'In you, ruby.',
#  'The pain',
#  'You wake to is not yours.',
#  'Love, love,',
#  'I have hung our cave with roses,',
#  'With soft rugs—',
#  'The last of Victoriana.',
#  'Let the stars',
#  'Plummet to their dark address,',
#  'Let the mercuric',
#  'Atoms that cripple drip',
#  'Into the terrible well,',
#  'You are the one',
#  'Solid the spaces lean on, envious.',
#  'You are the baby in the barn.',
#  'GULLIVER',
#  'Over your body the clouds go',
#  'High, high and icily',
#  'And a little flat, as if they',
#  'Floated on a glass that was invisible.',
#  'Unlike swans,',
#  'Having no reflections;',
#  'Unlike you,',
#  'With no strings attached.',
#  'AÍI cool, all blue. Unlike you—',
#  'You, there on your back,',
#  'Eyes to the sky.',
#  'The spider-men have caught you,',
#  'Winding and twining their petty fetters,',
#  'Their bribes—',
#  'So many silks.',
#  'How they hate you.',
#  'They converse in the valley of your fingers, they are inch-worms.',
#  'They would have you sleep in their cabinets,',
#  'This toe and that toe, a relic.',
#  'Step off!',
#  'Step off seven leagues, like those distances',
#  'That revolve in Crivelli, untouchable.',
#  'Let this eye be an eagle,',
#  'The shadow of this lip, an abyss.',
#  'GETTING THERE',
#  'How far is it?',
#  'How far is it now?',
#  'The gigantic gorilla interior',
#  'Of the wheels move, they appall me—',
#  'The terrible brains',
#  'Of Krupp, black muzzles',
#  'Revolving, the sound',
#  'Punching out Absence! like cannon.',
#  'It is Russia I have to get across, it is some war or other.',
#  'I am dragging my body',
#  'Quietly through the straw of the boxcars.',
#  'Now is the time for briberjy.',
#  'What do wheels eat, these wheels',
#  'Fixed to their arcs like gods,',
#  'The silver leash of the will—',
#  'Inexorable. And their pride!',
#  'All the gods know is destinations. I am a letter in this slot—',
#  'I fly to a name, two eyes.',
#  'Will there be fire, will there be bread?',
#  'Here there is such mud.',
#  'It is a trainstop, the nurses',
#  'Undergoing the faucet water, its veils, veils in a nunnery,',
#  'Touching their wounded,',
#  'The men the blood still pumps forward,',
#  'Legs, arms piled outside',
#  'The tent of unending cries—',
#  'A hospital of dolls.',
#  'And the men, what is left of the men',
#  'Pumped ahead by these pistons, this blood',
#  'Into the next mile,',
#  'The next hour—',
#  'Dynasty of broken arrows!',
#  'How far is it?',
#  'There is mud on my feet,',
#  'Thick, red and slipping. It is Adams side,',
#  'This earth I rise from, and I in agony.',
#  'I cannot undo myself, and the train is steaming.',
#  'Steaming and breathing, its teeth',
#  'Ready to roll, like a devil.',
#  'There is a minute at the end of it',
#  'A minute, a dewdrop.',
#  'How far is it?',
#  'It is so small',
#  'The place I am getting to, why are there these obstacles—',
#  'The body of this woman,',
#  'Charred skirts and deathmask',
#  'Mourned by religious figures, by garlanded children.',
#  'And now detonations—',
#  'Thunder and guns.',
#  "The fire's between us.",
#  'Is there no still place',
#  'Turning and turning in the middle air,',
#  'Untouched and untouchable.',
#  'The train is dragging itself, it is screaming—',
#  'An animal',
#  'Insane for the destination,',
#  'The bloodspot,',
#  'The face at the end of the flare.',
#  'I shall bury the wounded like pupas,',
#  'I shall count and bury the dead.',
#  'Let their souls writhe in a dew,',
#  'Incense in my track.',
#  'The carriages rock, they are cradles.',
#  'And 1, stepping from this skin',
#  'Of old bandages, boredoms, old faces',
#  'Step to you from the black car of Lethe,',
#  'Pure as a baby.',
#  'MEDUSA',
#  'Off that landspit of stony mouth-plugs,',
#  'Eyes rolled by white sticks,',
#  "Ears cupping the sea's incoherences,",
#  'You house your unnerving head—God-ball,',
#  'Lens of mercies,',
#  'Your stooges',
#  "Plying their wild cells in my keel's shadow,",
#  'Pushing by like hearts,',
#  'Red stigmata at the very center,',
#  'Riding the rip tide to the nearest point of departure,',
#  'Dragging their Jesus hair.',
#  'Did I escape, I wonder?',
#  'My mind winds to you',
#  'Old barnacled umbilicus, Atlantic cable,',
#  'Keeping itself, it seems, in a state of miraculous repair.',
#  'In any case, you are always there,',
#  'Tremulous breath at the end of my line,',
#  'Curve of water upleaping',
#  'To my water rod, dazzling and grateful,',
#  'Touching and sucking.',
#  'I didnt call you.',
#  'I didnt call you at all.',
#  'Nevertheless, nevertheless',
#  'You steamed to me over the sea,',
#  'Fat and red, a placenta',
#  'Paralyzing the kicking lovers.',
#  'Cobra light',
#  'Squeezing the breath from the blood bells',
#  'Of the fuchsia. I could draw no breath,',
#  'Dead and moneyless,',
#  'Overexposed, like an X-ray.',
#  'Who do you think you are?',
#  'A Communion wafer? Blubbery Mary?',
#  'I shall take no bite of your body,',
#  'Bottle in which I live,',
#  'Ghastly Vatican.',
#  'I am sick to death of hot salt.',
#  'Green as eunuchs, your wishes',
#  'Hiss at my sins.',
#  'Off, off, eely tentacle!',
#  'There is nothing between us.',
#  'THE MOON AND THE YEW TREE',
#  'This is the light of the mind, cold and planetary.',
#  'The trees of the mind are black. The light is blue.',
#  'The grasses unload their griefs on my feet as if I were God,',
#  'Prickling my ankles and murmuring of their humility.',
#  'Fumy, spiritous mists inhabit this place',
#  'Separated from my house by a row of headstones.',
#  'I simply cannot see where there is to get to.',
#  'The moon is no door. It is a face in its own right,',
#  'White as a knuckle and terribly upset.',
#  'It drags the sea after it like a dark crime; it is quiet',
#  'With the O-gape of complete despair. I live here.',
#  'Twice on Sunday, the bells startle the sky—',
#  'Eight great tongues affirming the Resurrection.',
#  'At the end, they soberly bong out their names.',
#  'The yew tree points up. It has a Gothic shape.',
#  'The eyes lift after it and find the moon.',
#  'The moon is my mother. She is not sweet like Mary.',
#  'Her blue garments unloose small bats and owls.',
#  'How I would like to believe in tenderness—',
#  'The face of the effigy, gentled by candles,',
#  'Bending, on me in particular, its mild eyes.',
#  'I have fallen a long way. Clouds are flowering',
#  'Blue and mystical over the face of the stars.',
#  'Inside the church, the saints will be all blue,',
#  'Floating on their delicate feet over the cold pews,',
#  'Their hands and faces stiff with holiness.',
#  'The moon sees nothing of this. She is bald and wild.',
#  'And the message of the yew tree is blackness—blackness and silence.',
#  'A BIRTHDAY PRESENT',
#  'What is this, behind this veil, is it ugly, is it beautiful?',
#  'It is shimmering, has it breasts, has it edges?',
#  'I am sure it is unique, I am sure it is just what I want.',
#  'When I am quiet at my cooking I feel it looking, I feel it thinking',
#  '“Is this the one I am to appear for,',
#  'Is this the elect one, the one with black eye-pits and a scar?',
#  'Measuring the flour, cutting off the surplus,',
#  'Adhering to rules, to rules, to rules.',
#  'Is this the one for the annunciation?',
#  'My god, what a laugh!”',
#  'But it shimmers, it does not stop, and I think it wants me.',
#  'I would not mind if it was bones, or a pearl button.',
#  'I do not want much of a present, anyway, this year.',
#  'After all I am alive only by accident.',
#  'I would have killed myself gladly that time any possible way.',
#  'Now there are these veils, shimmering like curtains,',
#  'The diaphanous satins of a January window',
#  'White as babies” bedding and glittering with dead breath. O ivory!',
#  'It must be a tusk there, a ghost-column.',
#  'Can you not see I do not mind what it is.',
#  'Can you not give it to me?',
#  'Do not be ashamed—_ do not mind if it is small.',
#  'Do not be mean, I am ready for enormity.',
#  'Let us sit down to it, one on either side, admiring the gleam,',
#  'The glaze, the mirrory variety of it.',
#  'Let us eat our last supper at it, like a hospital plate.',
#  'I know why you will not give it to me,',
#  'You are terrified',
#  'The world will go up in a shriek, and your head with it,',
#  'Bossed, brazen, an antique shield,',
#  'A marvel to your great-grandchildren.',
#  'Do not be afraid, it is not so.',
#  'I will only take it and go aside quietly.',
#  'You will not even hear me opening it, no paper crackle,',
#  'No falling ribbons, no scream at the end.',
#  'I do not think you credit me with this discretion.',
#  'If you only knew how the veils were killing my days.',
#  'To you they are only transparencies, clear air.',
#  'But my god, the clouds are like cotton.',
#  'Armies of them. They are carbon monoxide.',
#  'Sweetly, sweetly I breathe in,',
#  'Filling my veins with invisibles, with the million',
#  'Probable motes that tick the years off my life.',
#  'You are silver-suited for the occasion. O adding machine—',
#  'Is it impossible for you to let something go and have it go whole?',
#  'Must you stamp each piece in purple,',
#  'Must you kill what you can?',
#  'There is this one thing I want today, and only you can give it to me.',
#  'It stands at my window, big as the sky.',
#  'It breathes from my sheets, the cold dead center',
#  'Where split lives congeal and stiffen to history.',
#  'Let it not come by the mail, finger by finger.',
#  'Let it not come by word of mouth, I should be sixty',
#  'By the time the whole of it was delivered, and too numb to use it.',
#  'Only let down the veil, the veil, the veil.',
#  'If it were death',
#  'I would admire the deep gravity of it, its timeless eyes.',
#  'I would know you were serious.',
#  'There would be a nobility then, there would be a birthday.',
#  'And the knife not carve, but enter',
#  'Pure and clean as the cry of a baby,',
#  'And the universe slide from my side.',
#  'LETTER IN NOVEMBER',
#  'Love, the world',
#  'Suddenly turns, turns color. The streetlight',
#  "Splits through the rat's-tail",
#  'Pods of the laburnum at nine in the morning.',
#  'It is the Arctic,',
#  'This little black',
#  'Circle, with its tawn silk grasses—babies? hair.',
#  'There is a green in the air,',
#  'Soft, delectable.',
#  'It cushions me lovingly.',
#  'I am flushed and warm.',
#  'I think I may be enormous,',
#  'I am so stupidly happy,',
#  'My Wellingtons',
#  'Squelching and squelching through the beautiful red.',
#  'This is my property.',
#  'Two times a day',
#  'Í pace it, sniffing',
#  'The barbarous holly with its viridian',
#  'Scallops, pure iron,',
#  'And the wall of the old corpses.',
#  'I love them.',
#  'I love them like history.',
#  'The apples are golden,',
#  'Imagine it—',
#  'My seventy trees',
#  'Holding their gold-ruddy balls',
#  'In a thick gray death-soup,',
#  'Their million',
#  'Gold leaves metal and breathless.',
#  'O love, O celibate.',
#  'Nobody but me',
#  'Walks the waist-high wet.',
#  'The irreplaceable',
#  'Golds bleed and deepen, the mouths of Thermopylae.',
#  'THE RIVAL',
#  'If the moon smiled, she would resemble you.',
#  'You leave the same impression',
#  'Of something beautiful, but annihilating.',
#  'Both of you are great light borrowers.',
#  'Her O-mouth grieves at the world; yours is unaffected,',
#  'And your first gift is making stone out of everything.',
#  'I wake to a mausoleum; you are here,',
#  'Ticking your fingers on the marble table, looking for cigarettes,',
#  'Spiteful as a woman, but not so nervous,',
#  'And dying to say something unanswerable.',
#  'The moon, too, abases her subjects,',
#  'But in the daytime she is ridiculous.',
#  'Your dissatisfactions, on the other hand,',
#  'Arrive through the mailslot with loving regularity,',
#  'White and blank, expansive as carbon monoxide.',
#  'No day is safe from news of you,',
#  'Walking about in Africa maybe, but thinking of me.',
#  'DADDY',
#  'You do not do, you do not do',
#  'Any more, black shoe',
#  'In which I have lived like a foot',
#  'For thirty years, poor and white,',
#  'Barely daring to breathe or Achoo.',
#  'Daddy, I have had to kill you.',
#  'You died before I had time—',
#  'Marble-heavy, a bag full of God,',
#  'Ghastly statue with one grey toe',
#  'Big as a Frisco seal',
#  'And a head in the freakish Atlantic',
#  'Where it pours bean green over blue',
#  'In the waters off beautiful Nauset.',
#  'I used to pray to recover you.',
#  'Ach, du.',
#  'In the German tongue, in the Polish town',
#  'Scraped flat by the roller',
#  'Of wars, wars, wars.',
#  'But the name of the town is common.',
#  'My Polack friend',
#  'Says there are a dozen or two.',
#  'So I never could tell where you',
#  'Put your foot, your root,',
#  'I never could talk to you.',
#  'The tongue stuck in my jaw.',
#  'It stuck in a barb wire snare.',
#  'Ich, ich, ich, ich,',
#  'I could hardly speak.',
#  'I thought every German was you.',
#  'And the language obscene',
#  'An engine, an engine',
#  'Chuffing me off like a Jew.',
#  'A Jew to Dachau, Auschwitz, Belsen.',
#  'I began to talk like a Jew.',
#  'I think I may well be a Jew.',
#  'The snows of the Tvyrol, the clear beer of Vienna',
#  'Are not very pure or true.',
#  'With my gipsy ancestress and my weird luck',
#  'And my Taroc pack and my Taroc pack',
#  'I may be a bit of a Jew.',
#  'I have always been scared of you,',
#  'With your Luftwaffe, your gobbledygoo.',
#  'And your neat moustache',
#  'And your Aryan eye, bright blue.',
#  'Panzer-man, panzer-man, O You—',
#  'Not God but a swastika',
#  'So black no sky could squeak through.',
#  'Every woman adores a Fascist,',
#  'The boot in the face, the brute',
#  'Brute heart of a brute like you.',
#  'You stand at the blackboard, daddy,',
#  'In the picture I have of you,',
#  'A cleft in your chin instead of your foot',
#  'But no less a devil for that, no not',
#  'Any less the black man who',
#  'Bit my pretty red heart in two.',
#  'I was ten when they buried you.',
#  'At twenty I tried to die',
#  'And get back, back, back to you.',
#  'I thought even the bones would do.',
#  'But they pulled me out of the sack,',
#  'And they stuck me together with glue.',
#  'And then I knew what to do.',
#  'I made a model of you,',
#  'A man in black with a Meinkampf look',
#  'And a love of the rack and the screw.',
#  'And I said I do, I do.',
#  "So daddy, I'm finally through.",
#  'The black telephone off at the root,',
#  'The voices just cant worm through.',
#  "I've killed one man, I've killed two—",
#  'The vampire who said he was you',
#  'And drank my blood for a year,',
#  'Seven years, if you want to know.',
#  'Daddy, you can lie back now.',
#  "There's a stake in your fat black heart",
#  'And the villagers never liked you.',
#  'They are dancing and stamping on you.',
#  'They always knew it was you.',
#  'Daddy, daddy, you bastard, Im through.',
#  "YOU'RE",
#  'Clownlike, happiest on your hands,',
#  'Feet to the stars, and moon-skulled,',
#  'Gilled like a fish. A common-sense',
#  "Thumbs-down on the dodo's mode.",
#  'Wrapped up in yourself like a spool,',
#  'Trawling your dark as owls do.',
#  'Mute as a turnip from the Fourth',
#  'Of July to All Fools” Day,',
#  'O high-riser, my little loaf.',
#  'Vague as fog and looked for like mail.',
#  'Farther off than Australia.',
#  'Bent-backed Atlas, our traveled prawn.',
#  'Snug as a bud and at home',
#  'Like a sprat in a pickle jug.',
#  'A creel of eels, all ripples.',
#  'Jumpy as a Mexican bean.',
#  'Right, like a well-done sum.',
#  'A clean slate, with your own face on.',
#  'FEVER 103*',
#  'Pure? What does it mean?',
#  'The tongues of hell',
#  'Are dull, dull as the triple',
#  'Tongues of dull, fat Cerberus',
#  'Who wheezes at the gate. Incapable',
#  'Of licking clean',
#  'The aguey tendon, the sin, the sin.',
#  'The tinder cries.',
#  'The indelible smell',
#  'Of a snuffed candle!',
#  'Love, love, the low smokes roll',
#  "From me like Isadora's scarves, I'm in a fright",
#  'One scarf will catch and anchor in the wheel.',
#  'Such yellow sullen smokes',
#  'Make their own element. They will not rise,',
#  'But trundle round the globe',
#  'Choking the aged and the meek,',
#  'The weak',
#  'Hothouse baby in its crib,',
#  'The ghastly orchid',
#  'Hanging its hanging garden in the air,',
#  'Devilish leopard!',
#  'Radiation turned it white',
#  'And killed it in an hour.',
#  ...]

# %%
# set path to folder where text is
#folder = r"C:\Users\au576018\OneDrive - Aarhus Universitet\Documents\fabula\salmer\\"
folder = "/Users/au324704/Library/Mobile Documents/com~apple~CloudDocs/CHCAA/FABULANET/DA_literary_SA/annotation/"
# set filename for storing results
filename = 'plath_pascale'

# %%
len(data)
# Out:
# 1549

# %%
# make txt
out_txt = open(folder+filename+".txt", "w")

# paths for jsons
out_path_json = folder + filename + ".json"
out_path_json_full = folder+filename+"_ALL.json"

# %% [markdown]
# # Annotation instructions:
#
# Score each verse on valence, from negative to positive on the scale 0-10.
# Try not to think about the context too much, that is, try to evaluate each verse individually, independently from what preceded it.
# Some verses may not be complete senteces, since the sentences don not follow normal syntax while a sentence often includes several verses. Try not to worry about it, even if the words makes no sense. It is intented to be splitted up like this.
#
# When you run the below cell, the text, verse per verse will show up in the terminal above. Enter a number and press ENTER. Then the next verse will show up.
#
# Change the range before you start. The data contains 1914 verses in total. You just have to continue from where you left, if you need a break or don't have time to do them all.
# To exit the annotation, you can enter 's'. The results will be saved up to that point (every 10). Then just check the len of the dictionary at the bottom, set the annotation to start from this number
# and please remember to revise the pathnames above (so that you make a prv_savings_2.json, etc)

# %%
scores = []
json_scores = {}

# Open the txt file in write mode
with open(out_path_json, "w") as out_txt:
    for i in range(len(data)):
        s = data[i]
        print(str(i) + "\t" + s)
        score = input(s)

        # Check for STOP
        if score.lower() == 's':
            break

        scores.append([score, s])

        # add to json dictionary
        json_scores[i] = [score, s]

        if len(scores) % 10 == 0:
            for j in range(len(scores)):
                score = scores[j]
                # Writing to txt
                out_txt.write(str(j) + ',' + '\t' + score[0] + ',' + score[1] + "\n")

            # Writing to JSON
            with open(out_path_json, "a") as json_file:
                json.dump(json_scores, json_file)

# Put remaining scores in the full json file
with open(out_path_json_full, "a") as json_file_all:
    json.dump(json_scores, json_file_all)
# Out:
# 0	MORNING SONG
# 1	Love set you going like a fat gold watch.
# 2	The midwife slapped your footsoles, and your bald cry
# 3	Took its place among the elements.
# 4	Our voices echo, magnifying your arrival. New statue.
# 5	In a drafty museum, your nakedness
# 6	Shadows our safety. We stand round blankly as walls.
# 7	I'm no more your mother
# 8	Than the cloud that distills a mirror to reflect its own slow
# 9	Effacement at the wind 5 hand.
# 10	All night your moth-breath
# 11	Flickers among the flat pink roses. I wake to listen:
# 12	A far sea moves in my ear.
# 13	One cry, and I stumble from bed, cow-heavy and floral
# 14	In my Victorian nightgown.
# 15	Your mouth opens clean as a cats. The window square
# 16	Whitens and swallows its dull stars. And now you try
# 17	Your handful of notes;
# 18	The clear vowels rise like balloons.
# 19	THE COURIERS
# 20	The word of a snail on the plate of a leaf?
# 21	It is not mine. Do not accept it.
# 22	Acetic acid in a sealed tin?
# 23	Do not accept it. It is not genuine.
# 24	A ring of gold with the sun in it?
# 25	Lies. Lies and a grief.
# 26	Frost on a leaf, the immaculate
# 27	Cauldron, talking and crackling
# 28	All to itself on top of each
# 29	Of nine black Alps.
# 30	A disturbance in mirrors,
# 31	The sea shattering its gray one—
# 32	Love, love, my season.
# 33	SHEEP IN FOG
# 34	The hills step off into whiteness.
# 35	People or stars
# 36	Regard me sadly, I disappoint them.
# 37	The train leaves a line of breath.
# 38	O slow
# 39	Horse the color of rust,
# 40	Hooves, dolorous bells—
# 41	All morning the
# 42	Morning has been blackening,
# 43	A flower left out.
# 44	My bones hold a stillness, the far
# 45	Fields melt my heart.
# 46	They threaten
# 47	To let me through to a heaven
# 48	Starless and fatherless, a dark water.
# 49	THE APPLICANT
# 50	First, are you our sort of a person?
# 51	Do you wear
# 52	A glass eye, false teeth or a crutch,
# 53	A brace or a hook,
# 54	Rubber breasts or a rubber crotch,
# 55	Stitches to show something's missing? No, no? Then
# 56	How can we give you a thing?
# 57	Stop crying.
# 58	Open your hand.
# 59	Empty? Empty. Here is a hand
# 60	To fill it and willing
# 61	To bring teacups and roll away headaches
# 62	And do whatever you tell it.
# 63	Will you marry it?
# 64	It is guaranteed
# 65	To thumb shut your eyes at the end
# 66	And dissolve of sorrow.
# 67	We make new stock from the salt.
# 68	I notice you are stark naked.
# 69	How about this suit—
# 70	Black and stiff, but not a bad fit.
# 71	Will you marry it?
# 72	It is waterproof, shatterproof, proof
# 73	Against fire and bombs through the roof.
# 74	Believe me, they”Il bury you in it.
# 75	Now your head, excuse me, is empty.
# 76	I have the ticket for that.
# 77	Come here, sweetie, out of the closet.
# 78	Well, what do you think of that?
# 79	Naked as paper to start
# 80	But in twenty-five years she”ll be silver,
# 81	In fifty, gold.
# 82	A living doll, everywhere you look.
# 83	Tt can sew, it can cook,
# 84	It can talk, talk, talk.
# 85	It works, there is nothing wrong with it.
# 86	You have a hole, it's a poultice.
# 87	You have an eye, it's an image.
# 88	My boy, it's your last resort.
# 89	Will you marry it, marry it, marry it.
# 90	LADY LAZARUS
# 91	I have done it again.
# 92	One year in every ten
# 93	TI manage it—
# 94	A sort of walking miracle, my skin
# 95	Bright as a Nazi lampshade,
# 96	My right foot
# 97	A paperweight,
# 98	My face a featureless, fine
# 99	Jew linen.
# 100	Peel off the napkin
# 101	O my enemy.
# 102	Do I terrify?—
# 103	The nose, the eye pits, the full set of teeth?
# 104	The sour breath
# 105	Will vanish in a day.
# 106	Soon, soon the flesh
# 107	The grave cave ate will be
# 108	At home on me
# 109	And I a smiling woman. I am only thirty.
# 110	And like the cat I have nine times to die.
# 111	This is Number Three.
# 112	What a trash
# 113	To annihilate each decade.
# 114	What a million filaments.
# 115	The peanut-crunching crowd
# 116	Shoves in to see
# 117	Them unwrap me hand and foot—
# 118	The big strip tease.
# 119	Gentlemen, ladies
# 120	These are my hands
# 121	My knees.
# 122	I may be skin and bone,
# 123	Nevertheless, I am the same, identical woman.
# 124	The first time it happened I was ten.
# 125	Tt was an accident.
# 126	The second time I meant
# 127	To last it out and not come back at all.
# 128	I rocked shut
# 129	As a seashell.
# 130	They had to call and call
# 131	And pick the worms off me like sticky pearls.
# 132	Dying
# 133	Is an art, like everything else.
# 134	I do it exceptionally well.
# 135	I do it so it feels like hell.
# 136	I do it so it feels real.
# 137	I guess you could say Ive a call.
# 138	It's easy enough to do it in a cell.
# 139	It's easy enough to do it and stay put.
# 140	It's the theatrical
# 141	Comeback in broad day
# 142	To the same place, the same face, the same brute
# 143	Amused shout:
# 144	“A miracle!”
# 145	That knocks me out.
# 146	There is a charge
# 147	For the eyeing of my scars, there is a charge
# 148	For the hearing of my heart—
# 149	It really goes.
# 150	And there is a charge, a very large charge
# 151	For a word or a touch
# 152	Or a bit of blood
# 153	Or a piece of my hair or my clothes.
# 154	So, so, Herr Doktor.
# 155	So, Herr Enemy.
# 156	I am your opus, I am your valuable,
# 157	The pure gold baby
# 158	That melts to a shriek.
# 159	I turn and burn.
# 160	Do not think I underestimate your great concern.
# 161	Ash, ash—
# 162	You poke and stir.
# 163	Flesh, bone, there is nothing there—
# 164	A cake of soap,
# 165	A wedding ring,
# 166	A gold filling.
# 167	Herr God, Herr Lucifer
# 168	Beware
# 169	Beware.
# 170	Out of the ash
# 171	I rise with my red hair
# 172	And I eat men like air.
# 173	TULIPS
# 174	The tulips are too excitable, it is winter here.
# 175	Look how white everything is, how quiet, how snowed-in. I am learning peacefulness, lying by myself quietly
# 176	As the light lies on these white walls, this bed, these hands. I am nobody; I have nothing to do with explosions.
# 177	I have given my name and my day-clothes up to the nurses
# 178	And my history to the anaesthetist and my body to surgeons.
# 179	They have propped my head between the pillow and the sheet-cuff
# 180	Like an eye between two white lids that will not shut.
# 181	Stupid pupil, it has to take everything in.
# 182	The nurses pass and pass, they are no trouble,
# 183	They pass the way gulls pass inland in their white caps,
# 184	Doing things with their hands, one just the same as another,
# 185	So it is impossible to tell how many there are.
# 186	My body is a pebble to them, they tend it as water
# 187	Tends to the pebbles it must run over, smoothing them gently.
# 188	They bring me numbness in their bright needles, they bring me sleep.
# 189	Now I have lost myself I am sick of baggage—
# 190	My patent leather overnight case like a black pillbox,
# 191	My husband and child smiling out of the family photo;
# 192	Their smiles catch onto my skin, little smiling hooks.
# 193	I have let things slip, a thirty-year-old cargo boat
# 194	Stubbornly hanging on to my name and address.
# 195	They have swabbed me clear of my loving associations.
# 196	Scared and bare on the green plastic-pillowed trolley
# 197	I watched my teaset, my bureaus of linen, my books
# 198	Sink out of sight, and the water went over my head.
# 199	I am a nun now, I have never been so pure.
# 200	I didnt want any flowers, I only wanted
# 201	To lie with my hands turned up and be utterly empty.
# 202	How free it is, you have no idea how free—
# 203	The peacefulness is so big it dazes you,
# 204	And it asks nothing, a name tag, a few trinkets.
# 205	It is what the dead close on, finally; I imagine them
# 206	Shutting their mouths on it, like a Communion tablet.
# 207	The tulips are too red in the first place, they hurt me.
# 208	Even through the gift paper I could hear them breathe
# 209	Lightly, through their white swaddlings, like an awful baby.
# 210	Their redness talks to my wound, it corresponds.
# 211	They are subtle: they seem to float, though they weigh me down,
# 212	Upsetting me with their sudden tongues and their color,
# 213	A dozen red lead sinkers round my neck.
# 214	Nobody watched me before, now I am watched.
# 215	The tulips turn to me, and the window behind me
# 216	Where once a day the light slowly widens and slowly thins,
# 217	And I see myself, flat, ridiculous, a cut-paper shadow
# 218	Between the eye of the sun and the eyes of the tulips,
# 219	And I have no face, I have wanted to efface myself.
# 220	The vivid tulips eat my oxygen.
# 221	Before they came the air was calm enough,
# 222	Coming and going, breath by breath, without any fuss.
# 223	Then the tulips filled it up like a loud noise.
# 224	Now the air snags and eddies round them the way a river
# 225	Snags and eddies round a sunken rust-red engine.
# 226	They concentrate my attention, that was happy
# 227	Playing and resting without committing itself.
# 228	The walls, also, seem to be warming themselves.
# 229	The tulips should be behind bars like dangerous animals;
# 230	They are opening like the mouth of some great African cat,
# 231	And I am aware of my heart: it opens and closes
# 232	Its bowl of red blooms out of sheer love of me.
# 233	The water I taste is warm and salt, like the sea,
# 234	And comes from a country far away as health.
# 235	CUT
# 236	What a thrill—
# 237	My thumb instead of an onion.
# 238	The top quite gone
# 239	Except for a sort of a hinge
# 240	Of skin,
# 241	A flap like a hat,
# 242	Dead white.
# 243	Then that red plush.
# 244	Little pilgrim,
# 245	The Indians axed your scalp.
# 246	Your turkey wattle
# 247	Carpet rolls
# 248	Straight from the heart.
# 249	I step on it,
# 250	Clutching my bottle
# 251	Of pink fizz.
# 252	A celebration, this is.
# 253	Out of a gap
# 254	A million soldiers run,
# 255	Redcoats, every one.
# 256	Whose side are they on?
# 257	O my
# 258	Homunculus, I am ill.
# 259	I have taken a pill to kill
# 260	The thin
# 261	Papery feeling.
# 262	Saboteur,
# 263	Kamikaze man—
# 264	The stain on your
# 265	Gauze Ku Klux Klan
# 266	Babushka
# 267	Darkens and tarnishes and when
# 268	The balled
# 269	Pulp of your heart
# 270	Confronts its small
# 271	Mill of silence
# 272	How you jump—
# 273	Trepanned veteran,
# 274	Dirty girl,
# 275	Thumb stump.
# 276	ELM
# 277	I know the bottom, she says. I know it with my great tap root:
# 278	It is what you fear.
# 279	I do not fear it: I have been there.
# 280	Is it the sea you hear in me,
# 281	Its dissatisfactions?
# 282	Or the voice of nothing, that was your madness?
# 283	Love is a shadow.
# 284	How you lie and cry after it
# 285	Listen: these are its hooves: it has gone off, like a horse.
# 286	AI! night I shall gallop thus, impetuously,
# 287	Till your head is a stone, your pillow a little turf,
# 288	Echoing, echoing.
# 289	Or shall I bring you the sound of poisons?
# 290	This is rain now, this big hush.
# 291	And this is the fruit of it: tin-white, like arsenic.
# 292	I have suffered the atrocity of sunsets.
# 293	Scorched to the root
# 294	My red filaments burn and stand, a hand of wires.
# 295	Now I break up in pieces that fly about like clubs.
# 296	A wind of such violence
# 297	Will tolerate no bystanding: I must shriek.
# 298	The moon, also, is merciless: she would drag me
# 299	Cruelly, being barren.
# 300	Her radiance scathes me. Or perhaps I have caught her.
# 301	I let her go. I let her go
# 302	Diminished and flat, as after radical surgery.
# 303	How your bad dreams possess and endow me.
# 304	I am inhabited by a cry.
# 305	Nightly it flaps out
# 306	Looking, with its hooks, for something to love.
# 307	I am terrified by this dark thing
# 308	That sleeps in me;
# 309	All day I feel its soft, feathery turnings, its malignity.
# 310	Clouds pass and disperse.
# 311	Are those the faces of love, those pale irretrievables?
# 312	Is it for such I agitate my heart?
# 313	I am incapable of more knowledge.
# 314	What is this, this face
# 315	So murderous in its strangle of branches ?—
# 316	Its snaky acids hiss.
# 317	It petrifies the will. These are the isolate, slow faults
# 318	That kill, that kill, that kill.
# 319	THE NIGHT DANCES
# 320	A smile fell in the grass.
# 321	Irretrievable!
# 322	And how will your night dances
# 323	Lose themselves. In mathematics?
# 324	Such pure leaps and spirals—
# 325	Surely they travel
# 326	The world forever, I shall not entirely
# 327	Sit emptied of beauties, the gift
# 328	Of your small breath, the drenched grass
# 329	Smell of your sleeps, lilies, lilies.
# 330	Their flesh bears no relation.
# 331	Cold folds of ego, the calla,
# 332	And the tiger, embellishing itself—
# 333	Spots, and a spread of hot petals.
# 334	The comets
# 335	Have such a space to cross,
# 336	Such coldness, forgetfulness.
# 337	So your gestures flake off—
# 338	Warm and human, then their pink light
# 339	Bleeding and peeling
# 340	Through the black amnesias of heaven.
# 341	Why am I given
# 342	These lamps, these planets
# 343	Falling like blessings, like flakes
# 344	Six-sided, white
# 345	On my eyes, my lips, my hair
# 346	Touching and melting.
# 347	Nowhere.
# 348	POPPIES IN OCTOBER
# 349	Even the sun-clouds this morning cannot manage such skirts.
# 350	Nor the woman in the ambulance
# 351	Whose red heart blooms through her coat so astoundingly—
# 352	A gift, a love gift
# 353	Utterly unasked for
# 354	By a sky
# 355	Palely and flamily
# 356	Igniting its carbon monoxides, by eyes
# 357	Dulled to a halt under bowlers.
# 358	O my God, what am I
# 359	That these late mouths should cry open
# 360	In a forest of frost, in a dawn of cornflowers.
# 361	BERCK-PLAGE
# 362	This is the sea, then, this great abeyance.
# 363	How the sun poultice draws on my inflammation.
# 364	Electrifyingly-colored sherbets, scooped from the freeze
# 365	By pale girls, travel the air in scorched hands.
# 366	Why is it so quiet, what are they hiding?
# 367	I have two legs, and I move smilingly.
# 368	A sandy damper kills the vibrations;
# 369	It stretches for miles, the shrunk voices
# 370	Waving and crutchless, half their old size.
# 371	The line of the eye, scalded by these bald surfaces,
# 372	Boomerang like anchored elastics, hurting the owner.
# 373	Is it any wonder he puts on dark glasses?
# 374	Is it any wonder he affects a black cassock?
# 375	Here he comes now, among the mackerel gatherers
# 376	Who wall up their backs against him.
# 377	They are handling the black and green lozenges like the parts of a body.
# 378	The sea, that crystallized these,
# 379	Creeps away, many-snaked, with a long hiss of distress.
# 380	This black boot has no mercy for anybody.
# 381	Why should it, it is the hearse of a dead foot,
# 382	The high, dead, toeless foot of this priest
# 383	Who plumbs the well of his book,
# 384	The bent print bulging before him like scenery.
# 385	Obscene bikinis hide in the dunes,
# 386	Breasts and hips a confectioner 's sugar
# 387	Of little crystals, titillating the light,
# 388	While a green pool opens its eye,
# 389	Sick with what it has swallowed—
# 390	Limbs, images, shrieks. Behind the concrete bunkers
# 391	Two lovers unstick themselves.
# 392	O white sea-crockery,
# 393	What cupped sighs, what salt in the throat...
# 394	And the onlooker, trembling,
# 395	Drawn like a long material
# 396	Through a still virulence,
# 397	And a weed, hairy as privates.
# 398	On the balconies of the hotel, things are glittering.
# 399	Things, things—
# 400	Tubular steel wheelchairs, aluminum crutches.
# 401	Such salt-sweetness. Why should I walk
# 402	Beyond the breakwater, spotty with barnacles? I am not a nurse, white and attendant,
# 403	I am not a smile.
# 404	These children are after something, with hooks and cries,
# 405	And my heart too small to bandage their terrible faults.
# 406	This is the side of a man: his red ribs,
# 407	The nerves bursting like trees, and this is the surgeon:
# 408	One mirrory eye—
# 409	A facet of knowledge.
# 410	On a striped mattress in one room
# 411	An old man is vanishing.
# 412	There is no help in his weeping wife.
# 413	Where are the eye-stones, yellow and valuable,
# 414	And the tongue, sapphire of ash.
# 415	A wedding-cake face in a paper frill.
# 416	How superior he is now.
# 417	It is like possessing a saint.
# 418	The nurses in their wing-caps are no longer so beautiful;
# 419	They are browning, like touched gardenias.
# 420	The bed is rolled from the wall.
# 421	This is what it is to be complete. It is horrible.
# 422	Is he wearing pajamas or an evening suit
# 423	Under the glued sheet from which his powdery beak
# 424	Rises so whitely unbuffeted?
# 425	They propped his jaw with a book until it stiffened
# 426	And folded his hands, that were shaking: goodbye, goodbye.
# 427	Now the washed sheets fly in the sun,
# 428	The pillow cases are sweetening.
# 429	It is a blessing, it is a blessing:
# 430	The long coffin of soap-colored oak,
# 431	The curious bearers and the raw date
# 432	Engraving itself in silver with marvelous calm.
# 433	The grey sky lowers, the hills like a green sea
# 434	Run fold upon fold far off, concealing their hollows,
# 435	The hollows in which rock the thoughts of the wife—
# 436	Blunt, practical boats
# 437	Full of dresses and hats and china and married daughters.
# 438	In the parlor of the stone house
# 439	One curtain is flickering from the open window,
# 440	Flickering and pouring, a pitiful candle.
# 441	This is the tongue of the dead man: remember, remember.
# 442	How far he is now, his actions
# 443	Around him like livingroom furniture, like a décor.
# 444	As the pallors gather—
# 445	The pallors of hands and neighborly faces,
# 446	The elate pallors of flying iris.
# 447	They are flying off into nothing: remember us.
# 448	The empty benches of memory look over stones,
# 449	Marble facades with blue veins, and jelly-glassfuls of daffodils.
# 450	It is so beautiful up here: it is a stopping place.
# 451	The natural fatness of these lime leaves! —
# 452	Pollarded green balls, the trees march to church.
# 453	The voice of the priest, in thin air,
# 454	Meets the corpse at the gate,
# 455	Addressing it, while the hills roll the notes of the dead bell;
# 456	A glitter of wheat and crude earth.
# 457	What is the name of that color?—
# 458	Old blood of caked walls the sun heals,
# 459	Old blood of limb stumps, burnt hearts.
# 460	The widow with her black pocketbook and three daughters,
# 461	Necessary among the flowers,
# 462	Enfolds her face like fine linen,
# 463	Not to be spread again.
# 464	While a sky, wormy with put-by smiles,
# 465	Passes cloud after cloud.
# 466	And the bride flowers expend a freshness,
# 467	And the soul is a bride
# 468	In a still place, and the groom is red and forgetful, he is featureless.
# 469	Behind the glass of this car
# 470	The world purrs, shut-off and gentle.
# 471	And I am dark-suited and still, a member of the party,
# 472	Gliding up in low gear behind the cart.
# 473	And the priest is a vessel,
# 474	A tarred fabric, sorry and dull,
# 475	Following the coffin on its flowery cart like a beautiful woman,
# 476	A crest of breasts, eyelids and lips
# 477	Storming the hilltop.
# 478	Then, from the barred yard, the children
# 479	Smell the melt of shoe-blacking,
# 480	Their faces turning, wordless and slow,
# 481	Their eyes opening
# 482	On a wonderful thing—
# 483	Six round black hats in the grass and a lozenge of wood,
# 484	And a naked mouth, red and awkward.
# 485	For a minute the sky pours into the hole like plasma.
# 486	There is no hope, it is given up.
# 487	ARIEL
# 488	Stasis in darkness.
# 489	Then the substanceless blue
# 490	Pour of tor and distances.
# 491	God's lioness,
# 492	How one we grow,
# 493	Pivot of heels and knees! —The furrow
# 494	Splits and passes, sister to
# 495	The brown arc
# 496	Of the neck I cannot catch,
# 497	Nigger-eye
# 498	Berries cast dark
# 499	Hooks—
# 500	Black sweet blood mouthfuls,
# 501	Shadows.
# 502	Something else
# 503	Hauls me through air—
# 504	Thighs, hair;
# 505	Flakes from my heels.
# 506	White
# 507	Godiva, I unpeel—
# 508	Dead hands, dead stringencies.
# 509	And now I
# 510	Foam to wheat, a glitter of seas.
# 511	The child cry
# 512	Melts in the wall.
# 513	And I
# 514	Am the arrow,
# 515	The dew that flies
# 516	Suicidal, at one with the drive
# 517	Into the red
# 518	Eye, the cauldron of morning.
# 519	DEATH & CO.
# 520	Two, of course there are two.
# 521	It seems perfectly natural now—
# 522	The one who never looks up, whose eyes are lidded
# 523	And balled, like Blake's,
# 524	Who exhibits
# 525	The birthmarks that are his trademark—
# 526	The scald scar of water,
# 527	The nude
# 528	Verdigris of the condor.
# 529	I am red meat. His beak
# 530	Claps sidewise: I am not his yet.
# 531	He tells me how badly I photograph.
# 532	He tells me how sweet
# 533	The babies look in their hospital
# 534	Icebox, a simple
# 535	Frill at the neck,
# 536	Then the flutings of their lonian
# 537	Death-gowns,
# 538	Then two little feet.
# 539	He does not smile or smoke.
# 540	The other does that,
# 541	His hair long and plausive.
# 542	Bastard
# 543	Masturbating a glitter,
# 544	He wants to be loved.
# 545	I do not stir.
# 546	The frost makes a flower,
# 547	The dew makes a star,
# 548	The dead bell,
# 549	The dead bell.
# 550	Somebody done for.
# 551	NICK AND THE CLANDESTICK
# 552	I am a miner. The light burns blue.
# 553	Waxy stalactites
# 554	Drip and thicken, tears
# 555	The earthen womb
# 556	Exudes from its dead boredom.
# 557	Black bat airs
# 558	Wrap me, raggy shawls,
# 559	Cold homicides.
# 560	They weld to me like plums.
# 561	Old cave of calcium
# 562	Icicles, old echoer.
# 563	Even the newts are white,
# 564	Those holy Joes.
# 565	And the fish, the fish—
# 566	Christ! they are panes of ice,
# 567	A vice of knives,
# 568	A piranha
# 569	Religion, drinking
# 570	Its first communion out of my live toes.
# 571	The candle
# 572	Gulps and recovers its small altitude,
# 573	Its yellows hearten.
# 574	O love, how did you get here?
# 575	O embryo
# 576	Remembering, even in sleep,
# 577	Your crossed position.
# 578	The blood blooms clean
# 579	In you, ruby.
# 580	The pain
# 581	You wake to is not yours.
# 582	Love, love,
# 583	I have hung our cave with roses,
# 584	With soft rugs—
# 585	The last of Victoriana.
# 586	Let the stars
# 587	Plummet to their dark address,
# 588	Let the mercuric
# 589	Atoms that cripple drip
# 590	Into the terrible well,
# 591	You are the one
# 592	Solid the spaces lean on, envious.
# 593	You are the baby in the barn.
# 594	GULLIVER
# 595	Over your body the clouds go
# 596	High, high and icily
# 597	And a little flat, as if they
# 598	Floated on a glass that was invisible.
# 599	Unlike swans,
# 600	Having no reflections;
# 601	Unlike you,
# 602	With no strings attached.
# 603	AÍI cool, all blue. Unlike you—
# 604	You, there on your back,
# 605	Eyes to the sky.
# 606	The spider-men have caught you,
# 607	Winding and twining their petty fetters,
# 608	Their bribes—
# 609	So many silks.
# 610	How they hate you.
# 611	They converse in the valley of your fingers, they are inch-worms.
# 612	They would have you sleep in their cabinets,
# 613	This toe and that toe, a relic.
# 614	Step off!
# 615	Step off seven leagues, like those distances
# 616	That revolve in Crivelli, untouchable.
# 617	Let this eye be an eagle,
# 618	The shadow of this lip, an abyss.
# 619	GETTING THERE
# 620	How far is it?
# 621	How far is it now?
# 622	The gigantic gorilla interior
# 623	Of the wheels move, they appall me—
# 624	The terrible brains
# 625	Of Krupp, black muzzles
# 626	Revolving, the sound
# 627	Punching out Absence! like cannon.
# 628	It is Russia I have to get across, it is some war or other.
# 629	I am dragging my body
# 630	Quietly through the straw of the boxcars.
# 631	Now is the time for briberjy.
# 632	What do wheels eat, these wheels
# 633	Fixed to their arcs like gods,
# 634	The silver leash of the will—
# 635	Inexorable. And their pride!
# 636	All the gods know is destinations. I am a letter in this slot—
# 637	I fly to a name, two eyes.
# 638	Will there be fire, will there be bread?
# 639	Here there is such mud.
# 640	It is a trainstop, the nurses
# 641	Undergoing the faucet water, its veils, veils in a nunnery,
# 642	Touching their wounded,
# 643	The men the blood still pumps forward,
# 644	Legs, arms piled outside
# 645	The tent of unending cries—
# 646	A hospital of dolls.
# 647	And the men, what is left of the men
# 648	Pumped ahead by these pistons, this blood
# 649	Into the next mile,
# 650	The next hour—
# 651	Dynasty of broken arrows!
# 652	How far is it?
# 653	There is mud on my feet,
# 654	Thick, red and slipping. It is Adams side,
# 655	This earth I rise from, and I in agony.
# 656	I cannot undo myself, and the train is steaming.
# 657	Steaming and breathing, its teeth
# 658	Ready to roll, like a devil.
# 659	There is a minute at the end of it
# 660	A minute, a dewdrop.
# 661	How far is it?
# 662	It is so small
# 663	The place I am getting to, why are there these obstacles—
# 664	The body of this woman,
# 665	Charred skirts and deathmask
# 666	Mourned by religious figures, by garlanded children.
# 667	And now detonations—
# 668	Thunder and guns.
# 669	The fire's between us.
# 670	Is there no still place
# 671	Turning and turning in the middle air,
# 672	Untouched and untouchable.
# 673	The train is dragging itself, it is screaming—
# 674	An animal
# 675	Insane for the destination,
# 676	The bloodspot,
# 677	The face at the end of the flare.
# 678	I shall bury the wounded like pupas,
# 679	I shall count and bury the dead.
# 680	Let their souls writhe in a dew,
# 681	Incense in my track.
# 682	The carriages rock, they are cradles.
# 683	And 1, stepping from this skin
# 684	Of old bandages, boredoms, old faces
# 685	Step to you from the black car of Lethe,
# 686	Pure as a baby.
# 687	MEDUSA
# 688	Off that landspit of stony mouth-plugs,
# 689	Eyes rolled by white sticks,
# 690	Ears cupping the sea's incoherences,
# 691	You house your unnerving head—God-ball,
# 692	Lens of mercies,
# 693	Your stooges
# 694	Plying their wild cells in my keel's shadow,
# 695	Pushing by like hearts,
# 696	Red stigmata at the very center,
# 697	Riding the rip tide to the nearest point of departure,
# 698	Dragging their Jesus hair.
# 699	Did I escape, I wonder?
# 700	My mind winds to you
# 701	Old barnacled umbilicus, Atlantic cable,
# 702	Keeping itself, it seems, in a state of miraculous repair.
# 703	In any case, you are always there,
# 704	Tremulous breath at the end of my line,
# 705	Curve of water upleaping
# 706	To my water rod, dazzling and grateful,
# 707	Touching and sucking.
# 708	I didnt call you.
# 709	I didnt call you at all.
# 710	Nevertheless, nevertheless
# 711	You steamed to me over the sea,
# 712	Fat and red, a placenta
# 713	Paralyzing the kicking lovers.
# 714	Cobra light
# 715	Squeezing the breath from the blood bells
# 716	Of the fuchsia. I could draw no breath,
# 717	Dead and moneyless,
# 718	Overexposed, like an X-ray.
# 719	Who do you think you are?
# 720	A Communion wafer? Blubbery Mary?
# 721	I shall take no bite of your body,
# 722	Bottle in which I live,
# 723	Ghastly Vatican.
# 724	I am sick to death of hot salt.
# 725	Green as eunuchs, your wishes
# 726	Hiss at my sins.
# 727	Off, off, eely tentacle!
# 728	There is nothing between us.
# 729	THE MOON AND THE YEW TREE
# 730	This is the light of the mind, cold and planetary.
# 731	The trees of the mind are black. The light is blue.
# 732	The grasses unload their griefs on my feet as if I were God,
# 733	Prickling my ankles and murmuring of their humility.
# 734	Fumy, spiritous mists inhabit this place
# 735	Separated from my house by a row of headstones.
# 736	I simply cannot see where there is to get to.
# 737	The moon is no door. It is a face in its own right,
# 738	White as a knuckle and terribly upset.
# 739	It drags the sea after it like a dark crime; it is quiet
# 740	With the O-gape of complete despair. I live here.
# 741	Twice on Sunday, the bells startle the sky—
# 742	Eight great tongues affirming the Resurrection.
# 743	At the end, they soberly bong out their names.
# 744	The yew tree points up. It has a Gothic shape.
# 745	The eyes lift after it and find the moon.
# 746	The moon is my mother. She is not sweet like Mary.
# 747	Her blue garments unloose small bats and owls.
# 748	How I would like to believe in tenderness—
# 749	The face of the effigy, gentled by candles,
# 750	Bending, on me in particular, its mild eyes.
# 751	I have fallen a long way. Clouds are flowering
# 752	Blue and mystical over the face of the stars.
# 753	Inside the church, the saints will be all blue,
# 754	Floating on their delicate feet over the cold pews,
# 755	Their hands and faces stiff with holiness.
# 756	The moon sees nothing of this. She is bald and wild.
# 757	And the message of the yew tree is blackness—blackness and silence.
# 758	A BIRTHDAY PRESENT
# 759	What is this, behind this veil, is it ugly, is it beautiful?
# 760	It is shimmering, has it breasts, has it edges?
# 761	I am sure it is unique, I am sure it is just what I want.
# 762	When I am quiet at my cooking I feel it looking, I feel it thinking
# 763	“Is this the one I am to appear for,
# 764	Is this the elect one, the one with black eye-pits and a scar?
# 765	Measuring the flour, cutting off the surplus,
# 766	Adhering to rules, to rules, to rules.
# 767	Is this the one for the annunciation?
# 768	My god, what a laugh!”
# 769	But it shimmers, it does not stop, and I think it wants me.
# 770	I would not mind if it was bones, or a pearl button.
# 771	I do not want much of a present, anyway, this year.
# 772	After all I am alive only by accident.
# 773	I would have killed myself gladly that time any possible way.
# 774	Now there are these veils, shimmering like curtains,
# 775	The diaphanous satins of a January window
# 776	White as babies” bedding and glittering with dead breath. O ivory!
# 777	It must be a tusk there, a ghost-column.
# 778	Can you not see I do not mind what it is.
# 779	Can you not give it to me?
# 780	Do not be ashamed—_ do not mind if it is small.
# 781	Do not be mean, I am ready for enormity.
# 782	Let us sit down to it, one on either side, admiring the gleam,
# 783	The glaze, the mirrory variety of it.
# 784	Let us eat our last supper at it, like a hospital plate.
# 785	I know why you will not give it to me,
# 786	You are terrified
# 787	The world will go up in a shriek, and your head with it,
# 788	Bossed, brazen, an antique shield,
# 789	A marvel to your great-grandchildren.
# 790	Do not be afraid, it is not so.
# 791	I will only take it and go aside quietly.
# 792	You will not even hear me opening it, no paper crackle,
# 793	No falling ribbons, no scream at the end.
# 794	I do not think you credit me with this discretion.
# 795	If you only knew how the veils were killing my days.
# 796	To you they are only transparencies, clear air.
# 797	But my god, the clouds are like cotton.
# 798	Armies of them. They are carbon monoxide.
# 799	Sweetly, sweetly I breathe in,
# 800	Filling my veins with invisibles, with the million
# 801	Probable motes that tick the years off my life.
# 802	You are silver-suited for the occasion. O adding machine—
# 803	Is it impossible for you to let something go and have it go whole?
# 804	Must you stamp each piece in purple,
# 805	Must you kill what you can?
# 806	There is this one thing I want today, and only you can give it to me.
# 807	It stands at my window, big as the sky.
# 808	It breathes from my sheets, the cold dead center
# 809	Where split lives congeal and stiffen to history.
# 810	Let it not come by the mail, finger by finger.
# 811	Let it not come by word of mouth, I should be sixty
# 812	By the time the whole of it was delivered, and too numb to use it.
# 813	Only let down the veil, the veil, the veil.
# 814	If it were death
# 815	I would admire the deep gravity of it, its timeless eyes.
# 816	I would know you were serious.
# 817	There would be a nobility then, there would be a birthday.
# 818	And the knife not carve, but enter
# 819	Pure and clean as the cry of a baby,
# 820	And the universe slide from my side.
# 821	LETTER IN NOVEMBER
# 822	Love, the world
# 823	Suddenly turns, turns color. The streetlight
# 824	Splits through the rat's-tail
# 825	Pods of the laburnum at nine in the morning.
# 826	It is the Arctic,
# 827	This little black
# 828	Circle, with its tawn silk grasses—babies? hair.
# 829	There is a green in the air,
# 830	Soft, delectable.
# 831	It cushions me lovingly.
# 832	I am flushed and warm.
# 833	I think I may be enormous,
# 834	I am so stupidly happy,
# 835	My Wellingtons
# 836	Squelching and squelching through the beautiful red.
# 837	This is my property.
# 838	Two times a day
# 839	Í pace it, sniffing
# 840	The barbarous holly with its viridian
# 841	Scallops, pure iron,
# 842	And the wall of the old corpses.
# 843	I love them.
# 844	I love them like history.
# 845	The apples are golden,
# 846	Imagine it—
# 847	My seventy trees
# 848	Holding their gold-ruddy balls
# 849	In a thick gray death-soup,
# 850	Their million
# 851	Gold leaves metal and breathless.
# 852	O love, O celibate.
# 853	Nobody but me
# 854	Walks the waist-high wet.
# 855	The irreplaceable
# 856	Golds bleed and deepen, the mouths of Thermopylae.
# 857	THE RIVAL
# 858	If the moon smiled, she would resemble you.
# 859	You leave the same impression
# 860	Of something beautiful, but annihilating.
# 861	Both of you are great light borrowers.
# 862	Her O-mouth grieves at the world; yours is unaffected,
# 863	And your first gift is making stone out of everything.
# 864	I wake to a mausoleum; you are here,
# 865	Ticking your fingers on the marble table, looking for cigarettes,
# 866	Spiteful as a woman, but not so nervous,
# 867	And dying to say something unanswerable.
# 868	The moon, too, abases her subjects,
# 869	But in the daytime she is ridiculous.
# 870	Your dissatisfactions, on the other hand,
# 871	Arrive through the mailslot with loving regularity,
# 872	White and blank, expansive as carbon monoxide.
# 873	No day is safe from news of you,
# 874	Walking about in Africa maybe, but thinking of me.
# 875	DADDY
# 876	You do not do, you do not do
# 877	Any more, black shoe
# 878	In which I have lived like a foot
# 879	For thirty years, poor and white,
# 880	Barely daring to breathe or Achoo.
# 881	Daddy, I have had to kill you.
# 882	You died before I had time—
# 883	Marble-heavy, a bag full of God,
# 884	Ghastly statue with one grey toe
# 885	Big as a Frisco seal
# 886	And a head in the freakish Atlantic
# 887	Where it pours bean green over blue
# 888	In the waters off beautiful Nauset.
# 889	I used to pray to recover you.
# 890	Ach, du.
# 891	In the German tongue, in the Polish town
# 892	Scraped flat by the roller
# 893	Of wars, wars, wars.
# 894	But the name of the town is common.
# 895	My Polack friend
# 896	Says there are a dozen or two.
# 897	So I never could tell where you
# 898	Put your foot, your root,
# 899	I never could talk to you.
# 900	The tongue stuck in my jaw.
# 901	It stuck in a barb wire snare.
# 902	Ich, ich, ich, ich,
# 903	I could hardly speak.
# 904	I thought every German was you.
# 905	And the language obscene
# 906	An engine, an engine
# 907	Chuffing me off like a Jew.
# 908	A Jew to Dachau, Auschwitz, Belsen.
# 909	I began to talk like a Jew.
# 910	I think I may well be a Jew.
# 911	The snows of the Tvyrol, the clear beer of Vienna
# 912	Are not very pure or true.
# 913	With my gipsy ancestress and my weird luck
# 914	And my Taroc pack and my Taroc pack
# 915	I may be a bit of a Jew.
# 916	I have always been scared of you,
# 917	With your Luftwaffe, your gobbledygoo.
# 918	And your neat moustache
# 919	And your Aryan eye, bright blue.
# 920	Panzer-man, panzer-man, O You—
# 921	Not God but a swastika
# 922	So black no sky could squeak through.
# 923	Every woman adores a Fascist,
# 924	The boot in the face, the brute
# 925	Brute heart of a brute like you.
# 926	You stand at the blackboard, daddy,
# 927	In the picture I have of you,
# 928	A cleft in your chin instead of your foot
# 929	But no less a devil for that, no not
# 930	Any less the black man who
# 931	Bit my pretty red heart in two.
# 932	I was ten when they buried you.
# 933	At twenty I tried to die
# 934	And get back, back, back to you.
# 935	I thought even the bones would do.
# 936	But they pulled me out of the sack,
# 937	And they stuck me together with glue.
# 938	And then I knew what to do.
# 939	I made a model of you,
# 940	A man in black with a Meinkampf look
# 941	And a love of the rack and the screw.
# 942	And I said I do, I do.
# 943	So daddy, I'm finally through.
# 944	The black telephone off at the root,
# 945	The voices just cant worm through.
# 946	I've killed one man, I've killed two—
# 947	The vampire who said he was you
# 948	And drank my blood for a year,
# 949	Seven years, if you want to know.
# 950	Daddy, you can lie back now.
# 951	There's a stake in your fat black heart
# 952	And the villagers never liked you.
# 953	They are dancing and stamping on you.
# 954	They always knew it was you.
# 955	Daddy, daddy, you bastard, Im through.
# 956	YOU'RE
# 957	Clownlike, happiest on your hands,
# 958	Feet to the stars, and moon-skulled,
# 959	Gilled like a fish. A common-sense
# 960	Thumbs-down on the dodo's mode.
# 961	Wrapped up in yourself like a spool,
# 962	Trawling your dark as owls do.
# 963	Mute as a turnip from the Fourth
# 964	Of July to All Fools” Day,
# 965	O high-riser, my little loaf.
# 966	Vague as fog and looked for like mail.
# 967	Farther off than Australia.
# 968	Bent-backed Atlas, our traveled prawn.
# 969	Snug as a bud and at home
# 970	Like a sprat in a pickle jug.
# 971	A creel of eels, all ripples.
# 972	Jumpy as a Mexican bean.
# 973	Right, like a well-done sum.
# 974	A clean slate, with your own face on.
# 975	FEVER 103*
# 976	Pure? What does it mean?
# 977	The tongues of hell
# 978	Are dull, dull as the triple
# 979	Tongues of dull, fat Cerberus
# 980	Who wheezes at the gate. Incapable
# 981	Of licking clean
# 982	The aguey tendon, the sin, the sin.
# 983	The tinder cries.
# 984	The indelible smell
# 985	Of a snuffed candle!
# 986	Love, love, the low smokes roll
# 987	From me like Isadora's scarves, I'm in a fright
# 988	One scarf will catch and anchor in the wheel.
# 989	Such yellow sullen smokes
# 990	Make their own element. They will not rise,
# 991	But trundle round the globe
# 992	Choking the aged and the meek,
# 993	The weak
# 994	Hothouse baby in its crib,
# 995	The ghastly orchid
# 996	Hanging its hanging garden in the air,
# 997	Devilish leopard!
# 998	Radiation turned it white
# 999	And killed it in an hour.
# 1000	Greasing the bodies of adulterers
# 1001	Like Hiroshima ash and eating in.
# 1002	The sin. The sin.
# 1003	Darling, all night
# 1004	I have been flickering, off, on, off, on.
# 1005	The sheets grow heavy as a lecher 5 kiss.
# 1006	Three days. Three nights.
# 1007	Lemon water, chicken
# 1008	Water, water make me retch.
# 1009	I am too pure for you or anyone.
# 1010	Your body
# 1011	Hurts me as the world hurts God. TI am a lantern—
# 1012	My head a moon
# 1013	Of Japanese paper, my gold beaten skin
# 1014	Infinitely delicate and infinitely expensive.
# 1015	Does not my heat astound you. And my light.
# 1016	All by myself I am a huge camellia
# 1017	Glowing and coming and going, flush on flush.
# 1018	I think I am going up,
# 1019	I think I may rise—
# 1020	The beads of hot metal fly, and 1, love, I
# 1021	Am a pure acetylene
# 1022	Virgin
# 1023	Attended by roses,
# 1024	By kisses, by cherubim,
# 1025	By whatever these pink things mean.
# 1026	Not you, nor him
# 1027	Not him, nor him
# 1028	(My selves dissolving, old whore petticoats)—
# 1029	To Paradise.
# 1030	THE BEE MEETING
# 1031	Who are these people at the bridge to meet me? They are the villagers—
# 1032	The rector, the midwife, the sexton, the agent for bees.
# 1033	In my sleeveless summery dress I have no protection,
# 1034	And they are all gloved and covered, why did nobody tell me?
# 1035	They are smiling and taking out veils tacked to ancient hats.
# 1036	I am nude as a chicken neck, does nobody love me?
# 1037	Yes, here is the secretary of bees with her white shop smock,
# 1038	Buttoning the cuffs at my wrists and the slit from my neck to my knees.
# 1039	Now I am milkweed silk, the bees will not notice.
# 1040	They will not smell my fear, my fear, my fear.
# 1041	Which is the rector now, is it that man in black?
# 1042	Which is the midwife, is that her blue coat?
# 1043	Everybody is nodding a square black head, they are knights in visors,
# 1044	Breastplates of cheesecloth knotted under the armpits.
# 1045	Their smiles and their voices are changing. I am led through a
# 1046	beanfield.
# 1047	Strips of tinfoil winking like people,
# 1048	Feather dusters fanning their hands in a sea of bean flowers,
# 1049	Creamy bean flowers with black eyes and leaves like bored hearts.
# 1050	Is it blood clots the tendrils are dragging up that string?
# 1051	No, no, it is scarlet flowers that will one day be edible.
# 1052	Now they are giving me a fashionable white straw Italian hat
# 1053	And a black veil that molds to my face, they are making me one of them.
# 1054	They are leading me to the shorn grove, the circle of hives.
# 1055	Is it the hawthorn that smells so sick?
# 1056	The barren body of hawthorn, etherizing its children.
# 1057	Is it some operation that is taking place?
# 1058	It is the surgeon my neighbors are waiting for,
# 1059	This apparition in a green helmet,
# 1060	Shining gloves and white suit.
# 1061	Is it the butcher, the grocer, the postman, someone I know?
# 1062	I cannot run, [ am rooted, and the gorse hurts me
# 1063	With its yellow purses, its spiky armory.
# 1064	I could not run without having to run forever.
# 1065	The white hive is snug as a virgin,
# 1066	Sealing off her brood cells, her honey, and quietly humming.
# 1067	Smoke rolls and scarves in the grove.
# 1068	The mind of the hive thinks this is the end of everything.
# 1069	Here they come, the outriders, on their hysterical elastics.
# 1070	If [ stand very still, they will think I am cow parsley,
# 1071	A gullible head untouched by their animosity,
# 1072	Not even nodding, a personage in a hedgerow.
# 1073	The villagers open the chambers, they are hunting the queen.
# 1074	Is she hiding, is she eating honey? She is very clever.
# 1075	She is old, old, old, she must live another year, and she knows it.
# 1076	While in their fingerjoint cells the new virgins
# 1077	Dream of a duel they will win inevitably,
# 1078	A curtain of wax dividing them from the bride flight,
# 1079	The upflight of the murderess into a heaven that loves her.
# 1080	The villagers are moving the virgins, there will be no killing.
# 1081	The old queen does not show herself, is she so ungrateful'?
# 1082	I am exhausted, I am exhausted—
# 1083	Pillar of white in a blackout of knives.
# 1084	I am the magician's girl who does not flinch.
# 1085	The villagers are untying their disguises, they are shaking hands.
# 1086	Whose is that long white box in the grove, what have they accomplished,
# 1087	why am I cold.
# 1088	THE ARRIVAL OF DE BEE BOX
# 1089	I ordered this, this clean wood box
# 1090	Square as a chair and almost too heavy to lift.
# 1091	I would say it was the coffin of a midget
# 1092	Or a square baby
# 1093	Were there not such a din in it.
# 1094	The box is locked, it is dangerous.
# 1095	I have to live with it overnight
# 1096	And I cant keep away from it.
# 1097	There are no windows, so I cant see what is in there.
# 1098	There is only a little grid, no exit.
# 1099	I put my eye to the grid.
# 1100	It is dark, dark,
# 1101	With the swarmy feeling of African hands
# 1102	Minute and shrunk for export,
# 1103	Black on black, angrily clambering.
# 1104	How can I let them out?
# 1105	It is the noise that appalls me most of all,
# 1106	The unintelligible syllables.
# 1107	It is like a Roman mob,
# 1108	Small, taken one by one, but my god, together!
# 1109	I lay my ear to furious Latin.
# 1110	I am not a Caesar.
# 1111	I have simply ordered a box of maniacs.
# 1112	They can be sent back.
# 1113	They can die, I need feed them nothing, I am the owner.
# 1114	I wonder how hungry they are.
# 1115	I wonder if they would forget me
# 1116	If I just undid the locks and stood back and turned into a tree.
# 1117	There is the laburnum, its blond colonnades,
# 1118	And the petticoats of the cherry.
# 1119	They might ignore me immediately
# 1120	In my moon suit and funeral veil.
# 1121	I am no source of honey
# 1122	So why should they turn on me?
# 1123	Tomorrow I will be sweet God, I will set them free.
# 1124	The box is only temporary.
# 1125	STINGS
# 1126	Bare-handed, I hand the combs.
# 1127	The man in white smiles, bare-handed,
# 1128	Our cheesecloth gauntlets neat and sweet,
# 1129	The throats of our wrists brave lilies.
# 1130	He and I
# 1131	Have a thousand clean cells between us,
# 1132	Eight combs of yellow cups,
# 1133	And the hive itself a teacup,
# 1134	White with pink flowers on it,
# 1135	With excessive love I enameled it
# 1136	Thinking “Sweetness, sweetness”
# 1137	Brood cells gray as the fossils of shells
# 1138	Terrify me, they seem so old.
# 1139	What am I buying, wormy mahogany?
# 1140	Is there any queen at dll in it?
# 1141	If there is, she is old,
# 1142	Her wings torn shawls, her long body
# 1143	Rubbed of its plush—
# 1144	Poor and bare and unqueenly and even shameful.
# 1145	I stand in a column
# 1146	Of winged, unmiraculous women,
# 1147	Honey-drudgers.
# 1148	I am no drudge
# 1149	Though for years I have eaten dust
# 1150	And dried plates with my dense hair.
# 1151	And seen my strangeness evaporate,
# 1152	Blue dew from dangerous skin.
# 1153	Will they hate me,
# 1154	These women who only scurry,
# 1155	Whose news is the open cherry, the open clover?
# 1156	It is almost over.
# 1157	I am in control.
# 1158	Here is my honey-machine,
# 1159	It will work without thinking,
# 1160	Opening, in spring, like an industrious virgin
# 1161	To scour the creaming crests
# 1162	As the moon, for its ivory powders, scours the sea.
# 1163	A third person is watching.
# 1164	He has nothing to do with the bee-seller or with me.
# 1165	Now he is gone
# 1166	In eight great bounds, a great scapegoat.
# 1167	Here is his slipper, here is another,
# 1168	And here the square of white linen
# 1169	He wore instead of a hat.
# 1170	He was sweet,
# 1171	The sweat of his efforts a rain
# 1172	Tugging the world to fruit.
# 1173	The bees found him out,
# 1174	Molding onto his lips like lies,
# 1175	Complicating his features.
# 1176	They thought death was worth it, but I
# 1177	Have a self to recover, a queen.
# 1178	Is she dead, is she sleeping?
# 1179	Where has she been,
# 1180	With her lion-red body, her wings of glass?
# 1181	Now she is flying
# 1182	More terrible than she ever was, red
# 1183	Scar in the sky, red comet
# 1184	Over the engine that killed her—
# 1185	The mausoleum, the wax house.
# 1186	WINTERING
# 1187	This is the easy time, there is nothing doing.
# 1188	I have whirled the midwife's extractor,
# 1189	I have my honey,
# 1190	Six jars of it,
# 1191	Six cat's eyes in the wine cellar,
# 1192	Wintering in a dark without window
# 1193	At the heart of the house
# 1194	Next to the last tenant's rancid jam
# 1195	And the bottles of empty glitters—
# 1196	Sir So-and-so's gin.
# 1197	This is the room I have never been in.
# 1198	This is the room I could never breathe in.
# 1199	The black bunched in there like a bat,
# 1200	No light
# 1201	But the torch and its faint
# 1202	Chinese yellow on appalling objects—
# 1203	Black asininity. Decay.
# 1204	Possession.
# 1205	It is they who own me.
# 1206	Neither cruel nor indifferent,
# 1207	Only ignorant.
# 1208	This is the time of hanging on for the bees—the bees
# 1209	So slow I hardly know them,
# 1210	Filing like soldiers
# 1211	To the syrup tin
# 1212	To make up for the honey I”ve taken.
# 1213	Tate and Lyle keeps them going,
# 1214	The refined snow.
# 1215	It is Tate and Lyle they live on, instead of flowers.
# 1216	They take it. The cold sets in.
# 1217	Now they ball in a mass,
# 1218	Black
# 1219	Mind against all that white.
# 1220	The smile of the snow is white.
# 1221	It spreads itself out, a mile-long body of Meissen,
# 1222	Into which, on warm days,
# 1223	They can only carry their dead.
# 1224	The bees are all women,
# 1225	Maids and the long royal lady.
# 1226	They have got rid of the men,
# 1227	The blunt, clumsy stumblers, the boors.
# 1228	Winter is for wmen—
# 1229	The woman, still at her knitting,
# 1230	At the cradle of Spanish walnut,
# 1231	Her body a bulb in the cold and too dumb to think.
# 1232	Will the hive survive, will the gladiolas
# 1233	Succeed in banking their fires
# 1234	To enter another year?
# 1235	What will they taste of, the Christmas roses?
# 1236	The bees are flying. They taste the spring.
# 1237	THE HANGING MAN
# 1238	By the roots of my hair some god got hold of me.
# 1239	I sizzled in his blue volts like a desert prophet.
# 1240	The nights snapped out of sight like a lizard's eyelid:
# 1241	A world of bald white days in a shadeless socket.
# 1242	A vulturous boredom pinned me in this tree.
# 1243	If he were 1, he would do what I did.
# 1244	LITTLE FUGUE
# 1245	The yew's black fingers wag:
# 1246	Cold clouds go over.
# 1247	So the deaf and dumb
# 1248	Signal the blind, and are ignored.
# 1249	I like black statements.
# 1250	The featurelessness of that cloud, now!
# 1251	White as an eye dll over!
# 1252	The eye of the blind pianist
# 1253	At my table on the ship.
# 1254	He felt for his food.
# 1255	His fingers had the noses of weasels.
# 1256	I couldn t stop looking.
# 1257	He could hear Beethoven:
# 1258	Black yew, white cloud,
# 1259	The horrific complications.
# 1260	Finger-traps—a tumult of keys.
# 1261	Empty and silly as plates,
# 1262	So the blind smile.
# 1263	I envy the big noises,
# 1264	The yew hedge of the Grosse Fuge.
# 1265	Deafness is something else.
# 1266	Such a dark funnel, my father!
# 1267	Í see your voice
# 1268	Black and leafy, as in my childhood,
# 1269	A yew hedge of orders,
# 1270	Gothic and barbarous, pure German.
# 1271	Dead men cry from it.
# 1272	I am guilty of nothing.
# 1273	The yew my Christ, then.
# 1274	Is it not as tortured?
# 1275	And you, during the Great War
# 1276	In the California delicatessen
# 1277	Lopping the sausages!
# 1278	They color my sleep,
# 1279	Red, mottled, like cut necks.
# 1280	There was a silence!
# 1281	Great silence of another order.
# 1282	I was seven, I knew nothing.
# 1283	The world occurred.
# 1284	You had one leg, and a Prussian mind.
# 1285	Now similar clouds
# 1286	Are spreading their vacuous sheets.
# 1287	Do you say nothing?
# 1288	I am lame in the memory.
# 1289	I remember a blue eye,
# 1290	A briefcase of tangerines.
# 1291	This was a man, then!
# 1292	Death opened, like a black tree, blackly.
# 1293	I survive the while,
# 1294	Arranging my morning.
# 1295	These are my fingers, this my baby.
# 1296	The clouds are a marriage dress, of that pallor.
# 1297	YEARS
# 1298	They enter as animals from the outer
# 1299	Space of holly where spikes
# 1300	Are not thoughts I turn on, like a Yogi,
# 1301	But greenness, darkness so pure
# 1302	They freeze and are.
# 1303	O God, I am not like you
# 1304	In your vacuous black,
# 1305	Stars stuck all over, bright stupid confetti.
# 1306	Eternity bores me,
# 1307	I never wanted it.
# 1308	What I love is
# 1309	The piston in motion—
# 1310	My soul dies before it.
# 1311	And the hooves of the horses,
# 1312	Their merciless churn.
# 1313	And you, great Stasis—
# 1314	What is so great in that!
# 1315	Is it a tiger this year, this roar at the door?
# 1316	Is it a Christus,
# 1317	The awful
# 1318	God-bit in him
# 1319	Dying to fly and be done with it?
# 1320	The blood berries are themselves, they are very still.
# 1321	The hooves will not have it,
# 1322	In blue distance the pistons hiss.
# 1323	THE MUNICH MANNEQUINS
# 1324	Perfection is terrible, it cannot have children.
# 1325	Cold as snow breath, it tamps the womb
# 1326	Where the yew trees blow like hydras,
# 1327	The tree of life and the tree of life
# 1328	Unloosing their moons, month after month, to no purpose.
# 1329	The blood flood is the flood of love,
# 1330	The absolute sacrifice.
# 1331	It means: no more idols but me,
# 1332	Me and you.
# 1333	So, in their sulfur loveliness, in their smiles
# 1334	These mannequins lean tonight
# 1335	In Munich, morgue between Paris and Rome,
# 1336	Naked and bald in their furs,
# 1337	Orange lollies on silver sticks,
# 1338	Intolerable, without mind.
# 1339	The snow drops its pieces of darkness,
# 1340	Nobody's about. In the hotels
# 1341	Hands will be opening doors and setting
# 1342	Down shoes for a polish of carbon
# 1343	Into which broad toes will go tomorrow.
# 1344	O the domesticity of these windows,
# 1345	The baby lace, the green-leaved confectionery,
# 1346	The thick Germans slumbering in their bottomless Stolz.
# 1347	And the black phones on hooks
# 1348	Glittering
# 1349	Glittering and digesting
# 1350	Voicelessness. The snow has no voice.
# 1351	TOTEM
# 1352	The engine is killing the track, the track is silver,
# 1353	It stretches into the distance. It will be eaten nevertheless.
# 1354	Its running is useless.
# 1355	At nightfall there is the beauty of drowned fields,
# 1356	Dawn gilds the farmers like pigs,
# 1357	Swaying slightly in their thick suits,
# 1358	White towers of Smithfield ahead,
# 1359	Fat haunches and blood on their minds.
# 1360	There is no mercy in the glitter of cleavers,
# 1361	The butcher s guillotine that whispers: “How's this, how' this?”
# 1362	In the bowl the hare is aborted,
# 1363	Its baby head out of the way, embalmed in spice,
# 1364	Flayed of fur and humanity.
# 1365	Let us eat it like Plato's afterbirth,
# 1366	Let us eat it like Christ.
# 1367	These are the people that were important—
# 1368	Their round eyes, their teeth, their grimaces
# 1369	On a stick that rattles and clicks, a counterfeit snake.
# 1370	Shall the hood of the cobra appall me—
# 1371	The loneliness of its eye, the eye of the mountains
# 1372	Through which the sky eternally threads itself?
# 1373	The world is blood-hot and personal
# 1374	Dawn says, with its blood-flush.
# 1375	There is no terminus, only suitcases
# 1376	Out of which the same self unfolds like a suit
# 1377	Bald and shiny, with pockets of wishes,
# 1378	Notions and tickets, short circuits and folding mirrors. I am mad, calls the spider, waving its many arms.
# 1379	And in truth it is terrible,
# 1380	Multiplied in the eyes of the flies.
# 1381	They buzz like blue children
# 1382	In nets of the infinite,
# 1383	Roped in at the end by the one
# 1384	Death with its many sticks.
# 1385	PARALYTIC
# 1386	It happens. Will it go on?—
# 1387	My mind a rock,
# 1388	No fingers to grip, no tongue,
# 1389	My god the iron lung
# 1390	That loves me, pumps
# 1391	My two
# 1392	Dust bags in and out,
# 1393	Will not
# 1394	Let me relapse
# 1395	While the day outside glides by like ticker tape.
# 1396	The night brings violets,
# 1397	Tapestries of eyes,
# 1398	Lights,
# 1399	The soft anonymous
# 1400	Talkers: “You all right?”
# 1401	The starched, inaccessible breast.
# 1402	Dead egg, I lie
# 1403	Whole
# 1404	On a whole world I cannot touch,
# 1405	At the white, tight
# 1406	Drum of my sleeping couch
# 1407	Photographs visit me—
# 1408	My wife, dead and flat, in 1920 furs,
# 1409	Mouth full of pearls,
# 1410	Two girls
# 1411	As flat as she, who whisper “We”re your daughters.”
# 1412	The still waters
# 1413	Wrap my lips,
# 1414	Eyes, nose and ears,
# 1415	A clear
# 1416	Cellophane I cannot crack.
# 1417	On my bare back
# 1418	TI smile, a buddha, all
# 1419	Wants, desire
# 1420	Falling from me like rings
# 1421	Hugging their lights.
# 1422	The claw
# 1423	Of the magnolia,
# 1424	Drunk on its own scents,
# 1425	Asks nothing of life.
# 1426	BALLOONS
# 1427	Since Christmas they have lived with us,
# 1428	Guileless and clear,
# 1429	Oval soul-animals,
# 1430	Taking up half the space,
# 1431	Moving and rubbing on the silk
# 1432	Invisible air drifts,
# 1433	Giving a shriek and pop
# 1434	When attacked, then scooting to rest, barely trembling.
# 1435	Yellow cathead, blue fish—
# 1436	Such queer moons we live with
# 1437	Instead of dead furniture!
# 1438	Straw mats, white walls
# 1439	And these traveling
# 1440	Globes of thin air, red, green,
# 1441	Delighting
# 1442	The heart like wishes or free
# 1443	Peacocks blessing
# 1444	Old ground with a feather
# 1445	Beaten in starry metals.
# 1446	Your small
# 1447	Brother is making
# 1448	His balloon squeak like a cat.
# 1449	Seeming to see
# 1450	A funny pink world he might eat on the other side of it,
# 1451	He bites,
# 1452	Then sits
# 1453	Back, fat jug
# 1454	Contemplating a world clear as water.
# 1455	A red
# 1456	Shred in his little fist.
# 1457	POPPIES IN JULY
# 1458	Little poppies, little hell flames,
# 1459	Do you do no harm?
# 1460	You flicker. I cannot touch you.
# 1461	I put my hands among the flames. Nothing burns.
# 1462	And it exhausts me to watch you
# 1463	Flickering like that, wrinkly and clear red, like the skin of a mouth.
# 1464	A mouth just bloodied.
# 1465	Little bloody skirts!
# 1466	There are fumes that I cannot touch.
# 1467	Where are your opiates, your nauseous capsules?
# 1468	If I could bleed, or sleep! —
# 1469	If my mouth could marry a hurt like that!
# 1470	Or your liquors seep to me, in this glass capsule,
# 1471	Dulling and stilling.
# 1472	But colorless. Colorless.
# 1473	KINDNESS
# 1474	Kindness glides about my house.
# 1475	Dame Kindness, she is so nice!
# 1476	The blue and red jewels of her rings smoke
# 1477	In the windows, the mirrors
# 1478	Are filling with smiles.
# 1479	What is so real as the cry of a child?
# 1480	A rabbit's cry may be wilder
# 1481	But it has no soul.
# 1482	Sugar can cure everything, so Kindness says.
# 1483	Sugar is a necessary fluid,
# 1484	Its crystals a little poultice.
# 1485	A kindness, kindness
# 1486	Sweetly picking up pieces!
# 1487	My Japanese silks, desperate butterflies,
# 1488	May be pinned any minute, anesthetized.
# 1489	And here you come, with a cup of tea
# 1490	Wreathed in steam.
# 1491	The blood jet is poetry,
# 1492	There is no stopping it.
# 1493	You hand me two children, two roses.
# 1494	CONTUSION
# 1495	Color floods to the spot, dull purple.
# 1496	The rest of the body is all washed out,
# 1497	The color of pearl.
# 1498	In a pit of rock
# 1499	The sea sucks obsessively,
# 1500	One hollow the whole seas pivot.
# 1501	The size of a fly,
# 1502	The doom mark
# 1503	Crawls down the wall.
# 1504	The heart shuts,
# 1505	The sea slides back,
# 1506	The mirrors are sheeted.
# 1507	EDGE
# 1508	The woman is perfected.
# 1509	Her dead
# 1510	Body wears the smile of accomplishment,
# 1511	The illusion of a Greek necessity
# 1512	Flows in the scrolls of her toga,
# 1513	Her bare
# 1514	Feet seem to be saying:
# 1515	We have come so far, it is over.
# 1516	Each dead child coiled, a white serpent,
# 1517	One at each little
# 1518	Pitcher of milk, now empty.
# 1519	She has folded
# 1520	Them back into her body as petals
# 1521	Of a rose close when the garden
# 1522	Stiffens and odors bleed
# 1523	From the sweet, deep throats of the night flower.
# 1524	The moon has nothing to be sad about,
# 1525	Staring from her hood of bone.
# 1526	She is used to this sort of thing.
# 1527	Her blacks crackle and drag.
# 1528	WORDS
# 1529	Axes
# 1530	After whose stroke the wood rings,
# 1531	And the echoes!
# 1532	Echoes traveling
# 1533	Off from the center like horses.
# 1534	The sap
# 1535	Wells like tears, like the
# 1536	Water striving
# 1537	To re-establish its mirror
# 1538	Over the rock
# 1539	That drops and turns,
# 1540	A white skull,
# 1541	Eaten by weedy greens.
# 1542	Years later I
# 1543	Encounter them on the road—
# 1544	Words dry and riderless,
# 1545	The indefatigable hoof-taps.
# 1546	While
# 1547	From the bottom of the pool, fixed stars
# 1548	Govern a life.

# %%
with open(out_path_json_full, 'r') as file:
    annotated = json.load(file)

print(len(annotated))

pd.DataFrame.from_dict(annotated, orient='index', columns=['SCORE','SENTENCE'])
# Out:
# 63
#    SCORE                                   SENTENCE
# 0      5                           THE MANOR GARDEN
# 1      2  The fountains are dry and the roses over.
# 2      2     License of death. Your day approaches.
# 3      4      The pears fatten like little buddhas.
# 4      6          A blue mist is dragging the lake.
# ..   ...                                        ...
# 58     5                                     posed,
# 59                      Confounded inept guesswork:
# 60               Framed in windows of Main Street's
# 61                          Silver factory, immense
# 62                 Hammers hoisted, wheels turning,
#
# [63 rows x 2 columns]
